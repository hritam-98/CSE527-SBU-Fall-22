# %% [markdown]
# # CSE527 Homework 4
# **Due date: 11:59 pm EST on Nov. 1, 2022 (Tue.)**
#
# In this semester, we will use Google Colab for the assignments, which allows us to utilize resources that some of us might not have in their local machines such as GPUs. You will need to use your Stony Brook (*.stonybrook.edu) account for coding and Google Drive to save your results.
#
# ## Google Colab Tutorial
# ---
# Go to https://colab.research.google.com/notebooks/, you will see a tutorial named "Welcome to Colaboratory" file, where you can learn the basics of using google colab.
#
# Settings used for assignments: ***Edit -> Notebook Settings -> Runtime Type (Python 3)***.
#
#
# ## Description
# ---
# This project is an introduction to deep learning tools for computer vision. You will design and train deep convolutional networks for scene recognition using [PyTorch](http://pytorch.org). You can visualize the
# structure of the network with [mNeuron] (http://vision03.csail.mit.edu/cnn_art/index.html)
#
# In Problem 1 of the project you will train a deep convolutional network from scratch to recognize scenes. The starter codes gives you methods to load data and display them. You will need to define a simple network architecture and add jittering, normalization, and regularization to increase recognition accuracy to 50, 60, or perhaps 70%. Unfortunately, we only have 2,400 training examples so it doesn't seem possible to train a network from scratch which outperforms hand-crafted features
#
# For Problem 2 you will instead fine-tune a pre-trained deep network to achieve about 85% accuracy on the task. We will use the pretrained AlexNet network which was not trained to recognize scenes at all.
#
# These two approaches represent the most common approaches to recognition problems in computer vision today -- train a deep network from scratch if you have enough data (it's not always obvious whether or not you do), and if you cannot then instead fine-tune a pre-trained network.
#
# There are 2 problems in this homework with a total of 120 points including 20 bonus points. Be sure to read **Submission Guidelines** below. They are important. For the problems requiring text descriptions, you might want to add a markdown block for that.
#
# ## Dataset
# ---
# Save the [dataset(click me)](https://drive.google.com/open?id=1NWC3TMsXSWN2TeoYMCjhf2N1b-WRDh-M) into your working folder in your Google Drive for this homework. <br>
# Under your root folder, there should be a folder named "data" (i.e. XXX/Surname_Givenname_SBUID/data) containing the images.
#
# ## Some Tutorials (PyTorch)
# ---
# - You will be using PyTorch for deep learning toolbox (follow the [link](http://pytorch.org) for installation).
# - For PyTorch beginners, please read this [tutorial](http://pytorch.org/tutorials/beginner/deep_learning_60min_blitz.html) before doing your homework.
# - Feel free to study more tutorials at http://pytorch.org/tutorials/.
# - Find cool visualization here at http://playground.tensorflow.org.

# %%
# import packages here
import cv2
import numpy as np
import matplotlib.pyplot as plt
import glob
import random 
import time

import torch
import torchvision
import torchvision.transforms as transforms

from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F

# %%
# Mount your google drive where you've saved your assignment folder
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# Replace '------' with the path such that "Surname_Givenname_SBUID_hw*" is your working directory
# %cd '/content/gdrive/MyDrive/Basak_Hritam_114783055_HW4/'
# Out:
# /content/gdrive/MyDrive/Basak_Hritam_114783055_HW4

# %% [markdown]
# ## Problem 0: Loading and Preprocessing data
# ---
# (0 point) In this part, you are provided with a function that loads data into minibatches for training and testing in PyTorch. However, some preprocessing parts are missing. Your will need to implement them when doing Problem 1.

# %%
#--------------------------------------------------
#    Load Training Data and Testing Data
#--------------------------------------------------

def set_random_seed(seed):
     torch.manual_seed(seed)
     torch.cuda.manual_seed_all(seed)
     np.random.seed(seed)
     random.seed(seed)
     torch.backends.cudnn.deterministic = True
set_random_seed(0)

class_names = [name[13:] for name in glob.glob('./data/train/*')]
class_names = dict(zip(range(len(class_names)), class_names))
print("class_names: %s " % class_names)

def load_dataset(path, img_size, num_per_class=-1, batch_size=16, shuffle=False,
           augment=False, is_color=False, zero_centered=False):    
    data = []
    labels = []    
    channel_num = 3 if is_color else 1
        
    # read images and resizing
    for id, class_name in class_names.items():
        print("Loading images from class: %s" % id)
        img_path_class = glob.glob(path + class_name + '/*.jpg')
        if num_per_class > 0:
            img_path_class = img_path_class[:num_per_class]
        labels.extend([id]*len(img_path_class))
        for filename in img_path_class:
            if is_color:
                img = cv2.imread(filename)
            else:
                img = cv2.imread(filename, 0)
            
            # resize the image
            img = cv2.resize(img, img_size, cv2.INTER_LINEAR)
            
            if is_color:
                img = np.transpose(img, [2, 0, 1])
            
            # norm pixel values to [-1, 1]
            data.append(img.astype(np.float)/255*2-1)
            
    ##########--WRITE YOUR CODE HERE--##########
    # Data Augmentation 
    if augment: 
        #pass
        
        augmentation = [cv2.flip(img, 1) for img in data]
        

        data.extend(augmentation)
        labels.extend(labels)


    ##########-------END OF CODE-------##########    
    
    ##########--WRITE YOUR CODE HERE--##########
    # Data Normalization
    if zero_centered:
        #pass
        l = len(data)
        for k in range (l):
          mu, _ = cv2.meanStdDev(data[k])
          data[k] -= mu

        
    ##########-------END OF CODE-------##########
         
    # randomly permute (this step is important for training)
    if shuffle:
        bundle = list(zip(data, labels))
        random.shuffle(bundle)
        data, labels = zip(*bundle)
    
    # divide data into minibatches of TorchTensors
    if batch_size > 1:
        batch_data = []
        batch_labels = []
         
        for i in range(int(len(data) / batch_size)):
            minibatch_d = data[i*batch_size: (i+1)*batch_size]
            minibatch_d = np.reshape(minibatch_d, (batch_size, channel_num, img_size[0], img_size[1]))
            batch_data.append(torch.from_numpy(minibatch_d))

            minibatch_l = labels[i*batch_size: (i+1)*batch_size]
            batch_labels.append(torch.LongTensor(minibatch_l))
        data, labels = batch_data, batch_labels 
    
    return zip(batch_data, batch_labels)
# Out:
# class_names: {0: 'Office', 1: 'Store', 2: 'LivingRoom', 3: 'TallBuilding', 4: 'OpenCountry', 5: 'Suburb', 6: 'InsideCity', 7: 'Kitchen', 8: 'Street', 9: 'Mountain', 10: 'Industrial', 11: 'Highway', 12: 'Coast', 13: 'Bedroom', 14: 'Flower', 15: 'Forest'}

# %%
# load data into size (64, 64)
img_size = (64, 64)
batch_size = 64 # training sample number per batch

# load training dataset
trainloader_small = list(load_dataset('./data/train/', img_size, batch_size=batch_size, shuffle=True))
train_num = len(trainloader_small)
print("Finish loading %d minibatches (batch_size=%d) of training samples." % (train_num, batch_size))

# load testing dataset
testloader_small = list(load_dataset('./data/test/', img_size, num_per_class=50, batch_size=batch_size))
test_num = len(testloader_small)
print("Finish loading %d minibatches (batch_size=%d) of testing samples." % (test_num, batch_size))
# Out:
# Loading images from class: 0
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:43: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 37 minibatches (batch_size=64) of training samples.
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 6 minibatches (batch_size=64) of testing samples.

# %%
# show some images
def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    if len(npimg.shape) > 2:
        npimg = np.transpose(img, [1, 2, 0])
    plt.figure
    plt.imshow(npimg, 'gray')
    plt.show()
img, label = trainloader_small[0][0][11][0], trainloader_small[0][1][11]
label = int(np.array(label))
print(class_names[label])
imshow(img)
# Out:
# Forest

# %% [markdown]
# ## Problem 1: Training a Network From Scratch
# The days of hand designed features are gone. Now we have end-to-end learning in which a highly non-linear representation is learned for our data to maximize our objective function (in this case, 16-way classification accuracy). Let's start!

# %% [markdown]
# First, let's define a sample network architecture.

# %%
#--------------------------------------------------
#       Define Network Architecture
#--------------------------------------------------
class TNet(nn.Module):
    def __init__(self):
      super(TNet,self).__init__()  
           
      self.features = torch.nn.Sequential(
        nn.Conv2d(1, 16, 3),
        nn.ReLU(),
        nn.MaxPool2d(4, stride=4), 
      )
      
      self.classifier = nn.Sequential(
         nn.Linear(3600, 16), 
      )
      
    def forward(self, x):
      x = self.features(x)  
      x = torch.flatten(x, 1)
      x = self.classifier(x)
      return x

# %% [markdown]
# Then, let's define model training and evaluation functions.

# %%
#--------------------------------------------------
#       Model Training Function
#--------------------------------------------------
import torch.optim as optim
import time
  
def trainModel(net, trainloader, train_option, testloader=None):  
  loss_func = nn.CrossEntropyLoss()
  lr = train_option['lr']
  epoch = train_option['epoch']
  device = train_option['device'] if 'device' in train_option.keys() else 'cpu'
  log_iter = train_option['log_iter'] if 'log_iter' in train_option.keys() else 20
  eval_epoch = 1
  
  if 'optimizer' in train_option.keys():
    optimizer = train_option['optimizer']
  else:
    optimizer = optim.Adam(net.parameters(), lr=lr)

  start_time = time.time()
  if device == 'gpu':
    net = net.cuda()
    
  iters = 0
  running_loss = 0.0
  for ep in range(epoch):
    net.train()        
    for iter, (x, y) in enumerate(trainloader):
      iters += 1
      batch_x = Variable(x).float()
      batch_y = Variable(y).long()
      if device == 'gpu':
        batch_x = batch_x.cuda()
        batch_y = batch_y.cuda()

      outputs = net(batch_x)
      loss = loss_func(outputs, batch_y)
      optimizer.zero_grad()
      loss.backward()
      optimizer.step()
      running_loss += loss.item()
      
      time_lapse = time.strftime('%H:%M:%S', time.gmtime(time.time() - start_time))
      if iter % log_iter == 0:
        print('Epoch:{:2d} | Iter:{:5d} | Time: {} | Train Loss: {:.4f} | Average Loss: {:.4f} '.format(ep+1, iter, time_lapse, loss.item(), running_loss/iters))
   
    if testloader is not None and ep % eval_epoch == 0:
      evalModel(net, testloader)

# %%
#--------------------------------------------------
#       Model Evaluating Function
#--------------------------------------------------
import time
  
def evalModel(net, testloader): 
  acc = 0.0
  count = 0
  start_time = time.time()
  device = 'gpu' if next(net.parameters()).is_cuda else 'cpu'
  net.eval()
  
  for iter, (x, y) in enumerate(testloader):
        count += x.shape[0]
        batch_x = Variable(x).float()
        batch_y = Variable(y).long()
        if device == 'gpu':
          batch_x = batch_x.cuda()
          batch_y = batch_y.cuda()
        outputs = net(batch_x)
        acc += torch.sum(outputs.max(1)[1]==batch_y)
        
  time_lapse = time.strftime('%H:%M:%S', time.gmtime(time.time() - start_time))        
  print('Accuracy: {:5f} | Time: {}'.format(acc/count,time_lapse))

# %% [markdown]
# Finally, let's start training and evaluation.

# %%
#--------------------------------------------------
#       Start Training & Evaluation
#--------------------------------------------------
net = TNet() 
train_option = {}
train_option['lr'] = 0.002
train_option['epoch'] = 20
train_option['device'] = 'gpu'
trainModel(net, trainloader_small, train_option, testloader_small)
# Out:
# Epoch: 1 | Iter:    0 | Time: 00:00:11 | Train Loss: 2.7627 | Average Loss: 2.7627
# Epoch: 1 | Iter:   20 | Time: 00:00:11 | Train Loss: 2.2525 | Average Loss: 2.6243
# Accuracy: 0.354167 | Time: 00:00:00
# Epoch: 2 | Iter:    0 | Time: 00:00:11 | Train Loss: 1.6047 | Average Loss: 2.4335
# Epoch: 2 | Iter:   20 | Time: 00:00:11 | Train Loss: 1.6435 | Average Loss: 2.2250
# Accuracy: 0.367188 | Time: 00:00:00
# Epoch: 3 | Iter:    0 | Time: 00:00:11 | Train Loss: 1.2634 | Average Loss: 2.1128
# Epoch: 3 | Iter:   20 | Time: 00:00:12 | Train Loss: 1.3049 | Average Loss: 1.9752
# Accuracy: 0.403646 | Time: 00:00:00
# Epoch: 4 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.9898 | Average Loss: 1.8850
# Epoch: 4 | Iter:   20 | Time: 00:00:12 | Train Loss: 1.0232 | Average Loss: 1.7776
# Accuracy: 0.440104 | Time: 00:00:00
# Epoch: 5 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.7996 | Average Loss: 1.7025
# Epoch: 5 | Iter:   20 | Time: 00:00:12 | Train Loss: 0.7969 | Average Loss: 1.6141
# Accuracy: 0.445312 | Time: 00:00:00
# Epoch: 6 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.6780 | Average Loss: 1.5504
# Epoch: 6 | Iter:   20 | Time: 00:00:12 | Train Loss: 0.6115 | Average Loss: 1.4761
# Accuracy: 0.460938 | Time: 00:00:00
# Epoch: 7 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.6113 | Average Loss: 1.4219
# Epoch: 7 | Iter:   20 | Time: 00:00:12 | Train Loss: 0.4660 | Average Loss: 1.3590
# Accuracy: 0.460938 | Time: 00:00:00
# Epoch: 8 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.5993 | Average Loss: 1.3126
# Epoch: 8 | Iter:   20 | Time: 00:00:12 | Train Loss: 0.3922 | Average Loss: 1.2588
# Accuracy: 0.463542 | Time: 00:00:00
# Epoch: 9 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.6157 | Average Loss: 1.2186
# Epoch: 9 | Iter:   20 | Time: 00:00:13 | Train Loss: 0.3693 | Average Loss: 1.1724
# Accuracy: 0.455729 | Time: 00:00:00
# Epoch:10 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.5859 | Average Loss: 1.1371
# Epoch:10 | Iter:   20 | Time: 00:00:13 | Train Loss: 0.3420 | Average Loss: 1.0969
# Accuracy: 0.460938 | Time: 00:00:00
# Epoch:11 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.4609 | Average Loss: 1.0655
# Epoch:11 | Iter:   20 | Time: 00:00:13 | Train Loss: 0.2905 | Average Loss: 1.0298
# Accuracy: 0.466146 | Time: 00:00:00
# Epoch:12 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.3458 | Average Loss: 1.0021
# Epoch:12 | Iter:   20 | Time: 00:00:13 | Train Loss: 0.2405 | Average Loss: 0.9706
# Accuracy: 0.484375 | Time: 00:00:00
# Epoch:13 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.2807 | Average Loss: 0.9462
# Epoch:13 | Iter:   20 | Time: 00:00:13 | Train Loss: 0.2151 | Average Loss: 0.9187
# Accuracy: 0.481771 | Time: 00:00:00
# Epoch:14 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.2730 | Average Loss: 0.8973
# Epoch:14 | Iter:   20 | Time: 00:00:13 | Train Loss: 0.2400 | Average Loss: 0.8741
# Accuracy: 0.471354 | Time: 00:00:00
# Epoch:15 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.3325 | Average Loss: 0.8561
# Epoch:15 | Iter:   20 | Time: 00:00:14 | Train Loss: 0.3059 | Average Loss: 0.8371
# Accuracy: 0.458333 | Time: 00:00:00
# Epoch:16 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.5027 | Average Loss: 0.8233
# Epoch:16 | Iter:   20 | Time: 00:00:14 | Train Loss: 0.4268 | Average Loss: 0.8087
# Accuracy: 0.458333 | Time: 00:00:00
# Epoch:17 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.3947 | Average Loss: 0.7964
# Epoch:17 | Iter:   20 | Time: 00:00:14 | Train Loss: 0.2116 | Average Loss: 0.7819
# Accuracy: 0.463542 | Time: 00:00:00
# Epoch:18 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.3996 | Average Loss: 0.7684
# Epoch:18 | Iter:   20 | Time: 00:00:14 | Train Loss: 0.2382 | Average Loss: 0.7529
# Accuracy: 0.455729 | Time: 00:00:00
# Epoch:19 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.3986 | Average Loss: 0.7400
# Epoch:19 | Iter:   20 | Time: 00:00:14 | Train Loss: 0.3217 | Average Loss: 0.7248
# Accuracy: 0.466146 | Time: 00:00:00
# Epoch:20 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.2069 | Average Loss: 0.7119
# Epoch:20 | Iter:   20 | Time: 00:00:15 | Train Loss: 0.1673 | Average Loss: 0.6966
# Accuracy: 0.473958 | Time: 00:00:00

# %% [markdown]
# Great! You would get around 0.45-0.50 accuracy by this very simple network. Now it's your job to beat this result.
#
# ### Problem 1.1
# (35 points) Try to boost the accuracy by doing the following steps:
#
# **Data Augmentation**: We don't have enough training data, let's augment the training data.
# If you **left-right flip (mirror) an image** of a scene, it never changes categories. A kitchen doesn't become a forest when mirrored. This isn't true in all domains — a "d" becomes a "b" when mirrored, so you can't "jitter" digit recognition training data in the same way. But we can synthetically increase our amount of training data by left-right mirroring training images during the learning process.
#
# After you implement mirroring, you should notice that your training error doesn't drop as quickly. That's actually a good thing, because it means the network isn't overfitting to the 2,400 original training images as much (because it sees 4,800 training images now, although they're not as good as 4,800 truly independent samples). Because the training and test errors fall more slowly, you may need more training epochs or you may try modifying the learning rate. You are **required** to implement mirroring as data augmentation for this part.
#
# You can try more elaborate forms of jittering -- zooming in a random amount, rotating a random amount, taking a random crop, etc. These are not required, you might want to try these in the bonus part.
#
# **Data Normalization**: The images aren't **zero-centered**. One simple trick which can help a lot is to subtract the mean from every image. It would arguably be more proper to only compute the mean from the training images (since the test/validation images should be strictly held out) but it won't make much of a difference. This part is **required**.
#
# **Network Regularization**: Add **dropout layer**. If you train your network (especially for more than the default 30 epochs) you'll see that the training error can decrease to zero while the val top1 error hovers at 40% to 50%. The network has learned weights which can perfectly recognize the training data, but those weights don't generalize to held out test data. The best regularization would be more training data but we don't have that. Instead we will use dropout regularization.
#
# What does dropout regularization do? It randomly turns off network connections at training time to fight overfitting. This prevents a unit in one layer from relying too strongly on a single unit in the previous layer. Dropout regularization can be interpreted as simultaneously training many "thinned" versions of your network. At test, all connections are restored which is analogous to taking an average prediction over all of the "thinned" networks. You can see a more complete discussion of dropout regularization in this [paper](https://www.cs.toronto.edu/~hinton/absps/JMLRdropout.pdf).
#
# The dropout layer has only one free parameter — the dropout rate — the proportion of connections that are randomly deleted. The default of 0.5 should be fine. Insert a dropout layer between your convolutional layers. In particular, insert it directly before your last convolutional layer (and try others if that helps). Your train accuracy should decrease much more slowly. That's to be expected — you're making life much harder for the training algorithm by cutting out connections randomly. In this part, you are **required** to add dropout layer to your network.
#
# **Please give detailed descriptions of your network layout in the following format:**<br>
# Data augmentation: [descriptions]<br>
# Data normalization: [descriptions]<br>
# Layer 1: [layer_type]: [Parameters]<br>
# Layer 2: [layer_type]: [Parameters]<br>
# ...<br>
# **Then report the final accuracy on test set.**
#
# The minimum accuracy required for this section is **0.55**.

# %%
# load data into size (64, 64)
img_size = (64, 64)
batch_size = 64 # training sample number per batch

# load training dataset
trainloader_small = list(load_dataset('./data/train/', img_size, batch_size=batch_size, shuffle=True, augment=True, zero_centered=True))
train_num = len(trainloader_small)
print("Finish loading %d minibatches (batch_size=%d) of training samples." % (train_num, batch_size))

# load testing dataset
testloader_small = list(load_dataset('./data/test/', img_size, num_per_class=50, batch_size=batch_size, zero_centered=True))
test_num = len(testloader_small)
print("Finish loading %d minibatches (batch_size=%d) of testing samples." % (test_num, batch_size))
# Out:
# Loading images from class: 0
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:43: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 75 minibatches (batch_size=64) of training samples.
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 6 minibatches (batch_size=64) of testing samples.

# %%
#--------------------------------------------------
#       Define Network Architecture
#--------------------------------------------------
class HorNet(nn.Module):
    def __init__(self):
      super(HorNet,self).__init__()  
           
      self.features = torch.nn.Sequential(
        nn.Conv2d(1, 16, 3),
        nn.ReLU(),
        nn.MaxPool2d(4, stride=4), 
      )
      self.dropout = nn.Dropout(0.25)
      self.classifier = nn.Sequential(
         nn.Linear(3600, 16), 
      )
      
      
    def forward(self, x):
      x = self.features(x)  
      x = torch.flatten(x, 1)
      x = self.dropout(x)
      x = self.classifier(x)
      return x

# %%
#--------------------------------------------------
#       Start Training & Evaluation
#--------------------------------------------------
net = HorNet() 
train_option = {}
train_option['lr'] = 0.002
train_option['epoch'] = 60
train_option['device'] = 'gpu'
trainModel(net, trainloader_small, train_option, testloader_small)
# Out:
# Epoch: 1 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.7972 | Average Loss: 2.7972
# Epoch: 1 | Iter:   20 | Time: 00:00:00 | Train Loss: 2.4560 | Average Loss: 2.7793
# Epoch: 1 | Iter:   40 | Time: 00:00:00 | Train Loss: 2.3140 | Average Loss: 2.5644
# Epoch: 1 | Iter:   60 | Time: 00:00:00 | Train Loss: 1.9877 | Average Loss: 2.4214
# Accuracy: 0.424479 | Time: 00:00:00
# Epoch: 2 | Iter:    0 | Time: 00:00:00 | Train Loss: 1.6555 | Average Loss: 2.3226
# Epoch: 2 | Iter:   20 | Time: 00:00:00 | Train Loss: 1.7599 | Average Loss: 2.2025
# Epoch: 2 | Iter:   40 | Time: 00:00:00 | Train Loss: 1.8155 | Average Loss: 2.1199
# Epoch: 2 | Iter:   60 | Time: 00:00:00 | Train Loss: 1.5069 | Average Loss: 2.0522
# Accuracy: 0.437500 | Time: 00:00:00
# Epoch: 3 | Iter:    0 | Time: 00:00:00 | Train Loss: 1.2804 | Average Loss: 1.9955
# Epoch: 3 | Iter:   20 | Time: 00:00:00 | Train Loss: 1.4766 | Average Loss: 1.9268
# Epoch: 3 | Iter:   40 | Time: 00:00:00 | Train Loss: 1.5170 | Average Loss: 1.8745
# Epoch: 3 | Iter:   60 | Time: 00:00:00 | Train Loss: 1.3337 | Average Loss: 1.8281
# Accuracy: 0.473958 | Time: 00:00:00
# Epoch: 4 | Iter:    0 | Time: 00:00:00 | Train Loss: 1.2737 | Average Loss: 1.7921
# Epoch: 4 | Iter:   20 | Time: 00:00:00 | Train Loss: 1.3849 | Average Loss: 1.7434
# Epoch: 4 | Iter:   40 | Time: 00:00:00 | Train Loss: 1.1836 | Average Loss: 1.7044
# Epoch: 4 | Iter:   60 | Time: 00:00:00 | Train Loss: 1.2416 | Average Loss: 1.6711
# Accuracy: 0.500000 | Time: 00:00:00
# Epoch: 5 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.0554 | Average Loss: 1.6435
# Epoch: 5 | Iter:   20 | Time: 00:00:01 | Train Loss: 1.2686 | Average Loss: 1.6069
# Epoch: 5 | Iter:   40 | Time: 00:00:01 | Train Loss: 1.0218 | Average Loss: 1.5767
# Epoch: 5 | Iter:   60 | Time: 00:00:01 | Train Loss: 0.9927 | Average Loss: 1.5505
# Accuracy: 0.513021 | Time: 00:00:00
# Epoch: 6 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.0036 | Average Loss: 1.5288
# Epoch: 6 | Iter:   20 | Time: 00:00:01 | Train Loss: 1.2198 | Average Loss: 1.5009
# Epoch: 6 | Iter:   40 | Time: 00:00:01 | Train Loss: 1.0809 | Average Loss: 1.4757
# Epoch: 6 | Iter:   60 | Time: 00:00:01 | Train Loss: 0.9089 | Average Loss: 1.4531
# Accuracy: 0.518229 | Time: 00:00:00
# Epoch: 7 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.9068 | Average Loss: 1.4350
# Epoch: 7 | Iter:   20 | Time: 00:00:01 | Train Loss: 0.9864 | Average Loss: 1.4112
# Epoch: 7 | Iter:   40 | Time: 00:00:01 | Train Loss: 0.9917 | Average Loss: 1.3907
# Epoch: 7 | Iter:   60 | Time: 00:00:01 | Train Loss: 0.8020 | Average Loss: 1.3703
# Accuracy: 0.526042 | Time: 00:00:00
# Epoch: 8 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.7559 | Average Loss: 1.3543
# Epoch: 8 | Iter:   20 | Time: 00:00:01 | Train Loss: 0.9434 | Average Loss: 1.3340
# Epoch: 8 | Iter:   40 | Time: 00:00:01 | Train Loss: 0.9356 | Average Loss: 1.3165
# Epoch: 8 | Iter:   60 | Time: 00:00:01 | Train Loss: 0.8323 | Average Loss: 1.2995
# Accuracy: 0.505208 | Time: 00:00:00
# Epoch: 9 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.7927 | Average Loss: 1.2860
# Epoch: 9 | Iter:   20 | Time: 00:00:01 | Train Loss: 0.9346 | Average Loss: 1.2691
# Epoch: 9 | Iter:   40 | Time: 00:00:02 | Train Loss: 0.7420 | Average Loss: 1.2539
# Epoch: 9 | Iter:   60 | Time: 00:00:02 | Train Loss: 0.7960 | Average Loss: 1.2386
# Accuracy: 0.481771 | Time: 00:00:00
# Epoch:10 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.7662 | Average Loss: 1.2275
# Epoch:10 | Iter:   20 | Time: 00:00:02 | Train Loss: 0.8103 | Average Loss: 1.2131
# Epoch:10 | Iter:   40 | Time: 00:00:02 | Train Loss: 0.7977 | Average Loss: 1.2001
# Epoch:10 | Iter:   60 | Time: 00:00:02 | Train Loss: 0.6093 | Average Loss: 1.1867
# Accuracy: 0.497396 | Time: 00:00:00
# Epoch:11 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.6364 | Average Loss: 1.1766
# Epoch:11 | Iter:   20 | Time: 00:00:02 | Train Loss: 0.7587 | Average Loss: 1.1630
# Epoch:11 | Iter:   40 | Time: 00:00:02 | Train Loss: 0.8324 | Average Loss: 1.1513
# Epoch:11 | Iter:   60 | Time: 00:00:02 | Train Loss: 0.4964 | Average Loss: 1.1396
# Accuracy: 0.513021 | Time: 00:00:00
# Epoch:12 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.5539 | Average Loss: 1.1301
# Epoch:12 | Iter:   20 | Time: 00:00:02 | Train Loss: 0.8294 | Average Loss: 1.1182
# Epoch:12 | Iter:   40 | Time: 00:00:02 | Train Loss: 0.6717 | Average Loss: 1.1075
# Epoch:12 | Iter:   60 | Time: 00:00:02 | Train Loss: 0.5497 | Average Loss: 1.0966
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:13 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.6984 | Average Loss: 1.0882
# Epoch:13 | Iter:   20 | Time: 00:00:02 | Train Loss: 0.7966 | Average Loss: 1.0771
# Epoch:13 | Iter:   40 | Time: 00:00:02 | Train Loss: 0.6997 | Average Loss: 1.0667
# Epoch:13 | Iter:   60 | Time: 00:00:02 | Train Loss: 0.5461 | Average Loss: 1.0568
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:14 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.4998 | Average Loss: 1.0489
# Epoch:14 | Iter:   20 | Time: 00:00:03 | Train Loss: 0.5520 | Average Loss: 1.0388
# Epoch:14 | Iter:   40 | Time: 00:00:03 | Train Loss: 0.5974 | Average Loss: 1.0293
# Epoch:14 | Iter:   60 | Time: 00:00:03 | Train Loss: 0.5082 | Average Loss: 1.0202
# Accuracy: 0.515625 | Time: 00:00:00
# Epoch:15 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.5800 | Average Loss: 1.0130
# Epoch:15 | Iter:   20 | Time: 00:00:03 | Train Loss: 0.5232 | Average Loss: 1.0032
# Epoch:15 | Iter:   40 | Time: 00:00:03 | Train Loss: 0.6069 | Average Loss: 0.9938
# Epoch:15 | Iter:   60 | Time: 00:00:03 | Train Loss: 0.5850 | Average Loss: 0.9852
# Accuracy: 0.544271 | Time: 00:00:00
# Epoch:16 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.4050 | Average Loss: 0.9782
# Epoch:16 | Iter:   20 | Time: 00:00:03 | Train Loss: 0.6291 | Average Loss: 0.9697
# Epoch:16 | Iter:   40 | Time: 00:00:03 | Train Loss: 0.4841 | Average Loss: 0.9610
# Epoch:16 | Iter:   60 | Time: 00:00:03 | Train Loss: 0.4941 | Average Loss: 0.9524
# Accuracy: 0.544271 | Time: 00:00:00
# Epoch:17 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.4101 | Average Loss: 0.9455
# Epoch:17 | Iter:   20 | Time: 00:00:03 | Train Loss: 0.4479 | Average Loss: 0.9372
# Epoch:17 | Iter:   40 | Time: 00:00:03 | Train Loss: 0.4338 | Average Loss: 0.9293
# Epoch:17 | Iter:   60 | Time: 00:00:03 | Train Loss: 0.3927 | Average Loss: 0.9213
# Accuracy: 0.549479 | Time: 00:00:00
# Epoch:18 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.3993 | Average Loss: 0.9152
# Epoch:18 | Iter:   20 | Time: 00:00:04 | Train Loss: 0.5238 | Average Loss: 0.9077
# Epoch:18 | Iter:   40 | Time: 00:00:04 | Train Loss: 0.5240 | Average Loss: 0.9005
# Epoch:18 | Iter:   60 | Time: 00:00:04 | Train Loss: 0.3534 | Average Loss: 0.8932
# Accuracy: 0.572917 | Time: 00:00:00
# Epoch:19 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.3815 | Average Loss: 0.8875
# Epoch:19 | Iter:   20 | Time: 00:00:04 | Train Loss: 0.4019 | Average Loss: 0.8803
# Epoch:19 | Iter:   40 | Time: 00:00:04 | Train Loss: 0.5927 | Average Loss: 0.8739
# Epoch:19 | Iter:   60 | Time: 00:00:04 | Train Loss: 0.3832 | Average Loss: 0.8673
# Accuracy: 0.533854 | Time: 00:00:00
# Epoch:20 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.3218 | Average Loss: 0.8625
# Epoch:20 | Iter:   20 | Time: 00:00:04 | Train Loss: 0.4155 | Average Loss: 0.8556
# Epoch:20 | Iter:   40 | Time: 00:00:04 | Train Loss: 0.3167 | Average Loss: 0.8492
# Epoch:20 | Iter:   60 | Time: 00:00:04 | Train Loss: 0.2778 | Average Loss: 0.8425
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:21 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.2397 | Average Loss: 0.8376
# Epoch:21 | Iter:   20 | Time: 00:00:04 | Train Loss: 0.4811 | Average Loss: 0.8317
# Epoch:21 | Iter:   40 | Time: 00:00:04 | Train Loss: 0.3344 | Average Loss: 0.8254
# Epoch:21 | Iter:   60 | Time: 00:00:04 | Train Loss: 0.3285 | Average Loss: 0.8194
# Accuracy: 0.554688 | Time: 00:00:00
# Epoch:22 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.3922 | Average Loss: 0.8148
# Epoch:22 | Iter:   20 | Time: 00:00:04 | Train Loss: 0.5261 | Average Loss: 0.8091
# Epoch:22 | Iter:   40 | Time: 00:00:04 | Train Loss: 0.4012 | Average Loss: 0.8036
# Epoch:22 | Iter:   60 | Time: 00:00:05 | Train Loss: 0.2438 | Average Loss: 0.7981
# Accuracy: 0.580729 | Time: 00:00:00
# Epoch:23 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.4434 | Average Loss: 0.7938
# Epoch:23 | Iter:   20 | Time: 00:00:05 | Train Loss: 0.4391 | Average Loss: 0.7881
# Epoch:23 | Iter:   40 | Time: 00:00:05 | Train Loss: 0.3163 | Average Loss: 0.7826
# Epoch:23 | Iter:   60 | Time: 00:00:05 | Train Loss: 0.2446 | Average Loss: 0.7770
# Accuracy: 0.565104 | Time: 00:00:00
# Epoch:24 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.2842 | Average Loss: 0.7732
# Epoch:24 | Iter:   20 | Time: 00:00:05 | Train Loss: 0.3704 | Average Loss: 0.7678
# Epoch:24 | Iter:   40 | Time: 00:00:05 | Train Loss: 0.2602 | Average Loss: 0.7625
# Epoch:24 | Iter:   60 | Time: 00:00:05 | Train Loss: 0.2244 | Average Loss: 0.7576
# Accuracy: 0.544271 | Time: 00:00:00
# Epoch:25 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.2647 | Average Loss: 0.7537
# Epoch:25 | Iter:   20 | Time: 00:00:05 | Train Loss: 0.3934 | Average Loss: 0.7487
# Epoch:25 | Iter:   40 | Time: 00:00:05 | Train Loss: 0.4635 | Average Loss: 0.7438
# Epoch:25 | Iter:   60 | Time: 00:00:05 | Train Loss: 0.3534 | Average Loss: 0.7392
# Accuracy: 0.546875 | Time: 00:00:00
# Epoch:26 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.3386 | Average Loss: 0.7354
# Epoch:26 | Iter:   20 | Time: 00:00:05 | Train Loss: 0.3010 | Average Loss: 0.7307
# Epoch:26 | Iter:   40 | Time: 00:00:05 | Train Loss: 0.3561 | Average Loss: 0.7260
# Epoch:26 | Iter:   60 | Time: 00:00:05 | Train Loss: 0.2473 | Average Loss: 0.7213
# Accuracy: 0.549479 | Time: 00:00:00
# Epoch:27 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.1962 | Average Loss: 0.7180
# Epoch:27 | Iter:   20 | Time: 00:00:06 | Train Loss: 0.2252 | Average Loss: 0.7135
# Epoch:27 | Iter:   40 | Time: 00:00:06 | Train Loss: 0.3332 | Average Loss: 0.7089
# Epoch:27 | Iter:   60 | Time: 00:00:06 | Train Loss: 0.2319 | Average Loss: 0.7047
# Accuracy: 0.541667 | Time: 00:00:00
# Epoch:28 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.4268 | Average Loss: 0.7016
# Epoch:28 | Iter:   20 | Time: 00:00:06 | Train Loss: 0.2645 | Average Loss: 0.6975
# Epoch:28 | Iter:   40 | Time: 00:00:06 | Train Loss: 0.3949 | Average Loss: 0.6933
# Epoch:28 | Iter:   60 | Time: 00:00:06 | Train Loss: 0.3959 | Average Loss: 0.6892
# Accuracy: 0.549479 | Time: 00:00:00
# Epoch:29 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.1951 | Average Loss: 0.6864
# Epoch:29 | Iter:   20 | Time: 00:00:06 | Train Loss: 0.2137 | Average Loss: 0.6822
# Epoch:29 | Iter:   40 | Time: 00:00:06 | Train Loss: 0.4065 | Average Loss: 0.6783
# Epoch:29 | Iter:   60 | Time: 00:00:06 | Train Loss: 0.2285 | Average Loss: 0.6749
# Accuracy: 0.544271 | Time: 00:00:00
# Epoch:30 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.1595 | Average Loss: 0.6721
# Epoch:30 | Iter:   20 | Time: 00:00:06 | Train Loss: 0.4393 | Average Loss: 0.6685
# Epoch:30 | Iter:   40 | Time: 00:00:06 | Train Loss: 0.3229 | Average Loss: 0.6648
# Epoch:30 | Iter:   60 | Time: 00:00:06 | Train Loss: 0.2952 | Average Loss: 0.6613
# Accuracy: 0.533854 | Time: 00:00:00
# Epoch:31 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.1321 | Average Loss: 0.6586
# Epoch:31 | Iter:   20 | Time: 00:00:06 | Train Loss: 0.2633 | Average Loss: 0.6550
# Epoch:31 | Iter:   40 | Time: 00:00:07 | Train Loss: 0.2277 | Average Loss: 0.6514
# Epoch:31 | Iter:   60 | Time: 00:00:07 | Train Loss: 0.3224 | Average Loss: 0.6483
# Accuracy: 0.567708 | Time: 00:00:00
# Epoch:32 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.2584 | Average Loss: 0.6457
# Epoch:32 | Iter:   20 | Time: 00:00:07 | Train Loss: 0.2270 | Average Loss: 0.6424
# Epoch:32 | Iter:   40 | Time: 00:00:07 | Train Loss: 0.1706 | Average Loss: 0.6387
# Epoch:32 | Iter:   60 | Time: 00:00:07 | Train Loss: 0.3519 | Average Loss: 0.6354
# Accuracy: 0.554688 | Time: 00:00:00
# Epoch:33 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.2907 | Average Loss: 0.6330
# Epoch:33 | Iter:   20 | Time: 00:00:07 | Train Loss: 0.2697 | Average Loss: 0.6298
# Epoch:33 | Iter:   40 | Time: 00:00:07 | Train Loss: 0.1955 | Average Loss: 0.6265
# Epoch:33 | Iter:   60 | Time: 00:00:07 | Train Loss: 0.2070 | Average Loss: 0.6234
# Accuracy: 0.539062 | Time: 00:00:00
# Epoch:34 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.2069 | Average Loss: 0.6211
# Epoch:34 | Iter:   20 | Time: 00:00:07 | Train Loss: 0.1681 | Average Loss: 0.6183
# Epoch:34 | Iter:   40 | Time: 00:00:07 | Train Loss: 0.1849 | Average Loss: 0.6152
# Epoch:34 | Iter:   60 | Time: 00:00:07 | Train Loss: 0.1733 | Average Loss: 0.6121
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:35 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.1968 | Average Loss: 0.6100
# Epoch:35 | Iter:   20 | Time: 00:00:07 | Train Loss: 0.2018 | Average Loss: 0.6071
# Epoch:35 | Iter:   40 | Time: 00:00:07 | Train Loss: 0.2503 | Average Loss: 0.6042
# Epoch:35 | Iter:   60 | Time: 00:00:07 | Train Loss: 0.2759 | Average Loss: 0.6011
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:36 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.2279 | Average Loss: 0.5988
# Epoch:36 | Iter:   20 | Time: 00:00:08 | Train Loss: 0.2491 | Average Loss: 0.5960
# Epoch:36 | Iter:   40 | Time: 00:00:08 | Train Loss: 0.3747 | Average Loss: 0.5933
# Epoch:36 | Iter:   60 | Time: 00:00:08 | Train Loss: 0.1134 | Average Loss: 0.5905
# Accuracy: 0.526042 | Time: 00:00:00
# Epoch:37 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.2193 | Average Loss: 0.5883
# Epoch:37 | Iter:   20 | Time: 00:00:08 | Train Loss: 0.2701 | Average Loss: 0.5855
# Epoch:37 | Iter:   40 | Time: 00:00:08 | Train Loss: 0.2575 | Average Loss: 0.5828
# Epoch:37 | Iter:   60 | Time: 00:00:08 | Train Loss: 0.2253 | Average Loss: 0.5801
# Accuracy: 0.544271 | Time: 00:00:00
# Epoch:38 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.2132 | Average Loss: 0.5781
# Epoch:38 | Iter:   20 | Time: 00:00:08 | Train Loss: 0.2604 | Average Loss: 0.5756
# Epoch:38 | Iter:   40 | Time: 00:00:08 | Train Loss: 0.2766 | Average Loss: 0.5729
# Epoch:38 | Iter:   60 | Time: 00:00:08 | Train Loss: 0.1741 | Average Loss: 0.5702
# Accuracy: 0.549479 | Time: 00:00:00
# Epoch:39 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.3086 | Average Loss: 0.5682
# Epoch:39 | Iter:   20 | Time: 00:00:08 | Train Loss: 0.1685 | Average Loss: 0.5657
# Epoch:39 | Iter:   40 | Time: 00:00:08 | Train Loss: 0.4008 | Average Loss: 0.5633
# Epoch:39 | Iter:   60 | Time: 00:00:08 | Train Loss: 0.1839 | Average Loss: 0.5608
# Accuracy: 0.528646 | Time: 00:00:00
# Epoch:40 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.2025 | Average Loss: 0.5589
# Epoch:40 | Iter:   20 | Time: 00:00:08 | Train Loss: 0.1642 | Average Loss: 0.5563
# Epoch:40 | Iter:   40 | Time: 00:00:09 | Train Loss: 0.2368 | Average Loss: 0.5536
# Epoch:40 | Iter:   60 | Time: 00:00:09 | Train Loss: 0.1947 | Average Loss: 0.5512
# Accuracy: 0.552083 | Time: 00:00:00
# Epoch:41 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.2104 | Average Loss: 0.5492
# Epoch:41 | Iter:   20 | Time: 00:00:09 | Train Loss: 0.1461 | Average Loss: 0.5469
# Epoch:41 | Iter:   40 | Time: 00:00:09 | Train Loss: 0.1482 | Average Loss: 0.5445
# Epoch:41 | Iter:   60 | Time: 00:00:09 | Train Loss: 0.1266 | Average Loss: 0.5424
# Accuracy: 0.541667 | Time: 00:00:00
# Epoch:42 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.2309 | Average Loss: 0.5406
# Epoch:42 | Iter:   20 | Time: 00:00:09 | Train Loss: 0.4165 | Average Loss: 0.5383
# Epoch:42 | Iter:   40 | Time: 00:00:09 | Train Loss: 0.2786 | Average Loss: 0.5363
# Epoch:42 | Iter:   60 | Time: 00:00:09 | Train Loss: 0.1874 | Average Loss: 0.5344
# Accuracy: 0.526042 | Time: 00:00:00
# Epoch:43 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.3238 | Average Loss: 0.5330
# Epoch:43 | Iter:   20 | Time: 00:00:09 | Train Loss: 0.3028 | Average Loss: 0.5308
# Epoch:43 | Iter:   40 | Time: 00:00:09 | Train Loss: 0.1626 | Average Loss: 0.5288
# Epoch:43 | Iter:   60 | Time: 00:00:09 | Train Loss: 0.2287 | Average Loss: 0.5267
# Accuracy: 0.533854 | Time: 00:00:00
# Epoch:44 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.1994 | Average Loss: 0.5253
# Epoch:44 | Iter:   20 | Time: 00:00:09 | Train Loss: 0.2775 | Average Loss: 0.5234
# Epoch:44 | Iter:   40 | Time: 00:00:09 | Train Loss: 0.2233 | Average Loss: 0.5213
# Epoch:44 | Iter:   60 | Time: 00:00:09 | Train Loss: 0.2022 | Average Loss: 0.5195
# Accuracy: 0.552083 | Time: 00:00:00
# Epoch:45 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.1703 | Average Loss: 0.5180
# Epoch:45 | Iter:   20 | Time: 00:00:10 | Train Loss: 0.3789 | Average Loss: 0.5162
# Epoch:45 | Iter:   40 | Time: 00:00:10 | Train Loss: 0.1741 | Average Loss: 0.5144
# Epoch:45 | Iter:   60 | Time: 00:00:10 | Train Loss: 0.2591 | Average Loss: 0.5125
# Accuracy: 0.533854 | Time: 00:00:00
# Epoch:46 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.2640 | Average Loss: 0.5111
# Epoch:46 | Iter:   20 | Time: 00:00:10 | Train Loss: 0.3196 | Average Loss: 0.5093
# Epoch:46 | Iter:   40 | Time: 00:00:10 | Train Loss: 0.1512 | Average Loss: 0.5072
# Epoch:46 | Iter:   60 | Time: 00:00:10 | Train Loss: 0.2789 | Average Loss: 0.5054
# Accuracy: 0.533854 | Time: 00:00:00
# Epoch:47 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.1999 | Average Loss: 0.5039
# Epoch:47 | Iter:   20 | Time: 00:00:10 | Train Loss: 0.1672 | Average Loss: 0.5020
# Epoch:47 | Iter:   40 | Time: 00:00:10 | Train Loss: 0.2004 | Average Loss: 0.5002
# Epoch:47 | Iter:   60 | Time: 00:00:10 | Train Loss: 0.0859 | Average Loss: 0.4982
# Accuracy: 0.570312 | Time: 00:00:00
# Epoch:48 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.0880 | Average Loss: 0.4967
# Epoch:48 | Iter:   20 | Time: 00:00:10 | Train Loss: 0.1335 | Average Loss: 0.4949
# Epoch:48 | Iter:   40 | Time: 00:00:10 | Train Loss: 0.2193 | Average Loss: 0.4932
# Epoch:48 | Iter:   60 | Time: 00:00:10 | Train Loss: 0.3627 | Average Loss: 0.4916
# Accuracy: 0.578125 | Time: 00:00:00
# Epoch:49 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.0786 | Average Loss: 0.4901
# Epoch:49 | Iter:   20 | Time: 00:00:10 | Train Loss: 0.1688 | Average Loss: 0.4882
# Epoch:49 | Iter:   40 | Time: 00:00:11 | Train Loss: 0.1606 | Average Loss: 0.4863
# Epoch:49 | Iter:   60 | Time: 00:00:11 | Train Loss: 0.1829 | Average Loss: 0.4846
# Accuracy: 0.546875 | Time: 00:00:00
# Epoch:50 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.3370 | Average Loss: 0.4833
# Epoch:50 | Iter:   20 | Time: 00:00:11 | Train Loss: 0.1398 | Average Loss: 0.4815
# Epoch:50 | Iter:   40 | Time: 00:00:11 | Train Loss: 0.1285 | Average Loss: 0.4798
# Epoch:50 | Iter:   60 | Time: 00:00:11 | Train Loss: 0.0968 | Average Loss: 0.4781
# Accuracy: 0.554688 | Time: 00:00:00
# Epoch:51 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.2179 | Average Loss: 0.4767
# Epoch:51 | Iter:   20 | Time: 00:00:11 | Train Loss: 0.2524 | Average Loss: 0.4750
# Epoch:51 | Iter:   40 | Time: 00:00:11 | Train Loss: 0.1117 | Average Loss: 0.4732
# Epoch:51 | Iter:   60 | Time: 00:00:11 | Train Loss: 0.1309 | Average Loss: 0.4714
# Accuracy: 0.567708 | Time: 00:00:00
# Epoch:52 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.1030 | Average Loss: 0.4701
# Epoch:52 | Iter:   20 | Time: 00:00:11 | Train Loss: 0.1093 | Average Loss: 0.4684
# Epoch:52 | Iter:   40 | Time: 00:00:11 | Train Loss: 0.1791 | Average Loss: 0.4668
# Epoch:52 | Iter:   60 | Time: 00:00:11 | Train Loss: 0.1842 | Average Loss: 0.4652
# Accuracy: 0.533854 | Time: 00:00:00
# Epoch:53 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.2118 | Average Loss: 0.4640
# Epoch:53 | Iter:   20 | Time: 00:00:11 | Train Loss: 0.1834 | Average Loss: 0.4623
# Epoch:53 | Iter:   40 | Time: 00:00:11 | Train Loss: 0.2378 | Average Loss: 0.4606
# Epoch:53 | Iter:   60 | Time: 00:00:12 | Train Loss: 0.1192 | Average Loss: 0.4590
# Accuracy: 0.536458 | Time: 00:00:00
# Epoch:54 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.0960 | Average Loss: 0.4577
# Epoch:54 | Iter:   20 | Time: 00:00:12 | Train Loss: 0.1270 | Average Loss: 0.4561
# Epoch:54 | Iter:   40 | Time: 00:00:12 | Train Loss: 0.1738 | Average Loss: 0.4545
# Epoch:54 | Iter:   60 | Time: 00:00:12 | Train Loss: 0.1137 | Average Loss: 0.4531
# Accuracy: 0.539062 | Time: 00:00:00
# Epoch:55 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.1396 | Average Loss: 0.4520
# Epoch:55 | Iter:   20 | Time: 00:00:12 | Train Loss: 0.1617 | Average Loss: 0.4504
# Epoch:55 | Iter:   40 | Time: 00:00:12 | Train Loss: 0.2170 | Average Loss: 0.4489
# Epoch:55 | Iter:   60 | Time: 00:00:12 | Train Loss: 0.1724 | Average Loss: 0.4474
# Accuracy: 0.554688 | Time: 00:00:00
# Epoch:56 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.1838 | Average Loss: 0.4463
# Epoch:56 | Iter:   20 | Time: 00:00:12 | Train Loss: 0.1809 | Average Loss: 0.4448
# Epoch:56 | Iter:   40 | Time: 00:00:12 | Train Loss: 0.1700 | Average Loss: 0.4434
# Epoch:56 | Iter:   60 | Time: 00:00:12 | Train Loss: 0.1356 | Average Loss: 0.4419
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:57 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.0892 | Average Loss: 0.4408
# Epoch:57 | Iter:   20 | Time: 00:00:12 | Train Loss: 0.1668 | Average Loss: 0.4393
# Epoch:57 | Iter:   40 | Time: 00:00:12 | Train Loss: 0.2258 | Average Loss: 0.4379
# Epoch:57 | Iter:   60 | Time: 00:00:12 | Train Loss: 0.1033 | Average Loss: 0.4364
# Accuracy: 0.544271 | Time: 00:00:00
# Epoch:58 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.1121 | Average Loss: 0.4354
# Epoch:58 | Iter:   20 | Time: 00:00:13 | Train Loss: 0.1391 | Average Loss: 0.4339
# Epoch:58 | Iter:   40 | Time: 00:00:13 | Train Loss: 0.0888 | Average Loss: 0.4325
# Epoch:58 | Iter:   60 | Time: 00:00:13 | Train Loss: 0.1585 | Average Loss: 0.4312
# Accuracy: 0.533854 | Time: 00:00:00
# Epoch:59 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.0792 | Average Loss: 0.4302
# Epoch:59 | Iter:   20 | Time: 00:00:13 | Train Loss: 0.1837 | Average Loss: 0.4288
# Epoch:59 | Iter:   40 | Time: 00:00:13 | Train Loss: 0.0834 | Average Loss: 0.4274
# Epoch:59 | Iter:   60 | Time: 00:00:13 | Train Loss: 0.1542 | Average Loss: 0.4260
# Accuracy: 0.533854 | Time: 00:00:00
# Epoch:60 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.1344 | Average Loss: 0.4250
# Epoch:60 | Iter:   20 | Time: 00:00:13 | Train Loss: 0.1216 | Average Loss: 0.4236
# Epoch:60 | Iter:   40 | Time: 00:00:13 | Train Loss: 0.0685 | Average Loss: 0.4222
# Epoch:60 | Iter:   60 | Time: 00:00:13 | Train Loss: 0.1013 | Average Loss: 0.4208
# Accuracy: 0.528646 | Time: 00:00:00

# %% [markdown]
# **Answer**:
#
# Data augmentation: The image is flipped horizontally to get the augmented image
#
# Data normalization: First we calculated the mean and then subtracted from the image, which resulted in zero-centered image
#
# Layer 1: Same as the sample network given. It has 16 output channels. This is followed by ReLU activation and MaxPooling layers
#
# Layer 2: NN layer with 3600 input node and 16 output nodes. Dropout with p=0.25 was also added before this
#
#
# ...
#
# Accuray on test set: **0.580729** (best epoch)

# %% [markdown]
# ## Problem 1.2
#
# (15 points) Try **three different techniques** taught in the class to increase the accuracy of your model. Such as increasing training data by randomly rotating training images, adding batch normalization, different activation functions (e.g., sigmoid) and model architecture modification. Note that too many layers can do you no good due to insufficient training data. Clearly describe your method and accuracy increase/decrease for each of the three techniques.
#
# The minimum accuracy required for this section is **0.60**. (At least one Technique should achieve this)
#
# ### Technique 1

# %%
#--------------------------------------------------
#    Load Training Data and Testing Data
#--------------------------------------------------
# load data into size (64, 64)
img_size = (64, 64)

batch_size = 64         # training sample number per batch

# load training dataset

trainloader_small = list(load_dataset('./data/train/', img_size, batch_size=batch_size, shuffle=True, augment=False, zero_centered=True))
train_num = len(trainloader_small)
print("Finish loading %d minibatches (batch_size=%d) of training samples." % (train_num, batch_size))

# load testing dataset
testloader_small = list(load_dataset('./data/test/', img_size, num_per_class=50, batch_size=batch_size, zero_centered=True))
test_num = len(testloader_small)
print("Finish loading %d minibatches (batch_size=%d) of testing samples." % (test_num, batch_size))
# Out:
# Loading images from class: 0
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:43: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 37 minibatches (batch_size=64) of training samples.
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 6 minibatches (batch_size=64) of testing samples.

# %%
#--------------------------------------------------
#       Define Network Architecture
#--------------------------------------------------
class HorNet(nn.Module):
    def __init__(self):
      super(HorNet,self).__init__()  
           
      self.layer1 = torch.nn.Sequential(
        nn.Conv2d(1, 64, 3),
        nn.ReLU(),
        nn.MaxPool2d(4, stride=4)
      )
      self.layer2 = torch.nn.Sequential(
        nn.Conv2d(64, 128, 3),
        nn.Sigmoid(),
        nn.MaxPool2d(2, stride=2) 
      )

      self.dropout = nn.Dropout(0.25)      
      
      self.classifier = nn.Sequential(
         nn.Linear(4608, 16) 
      )

      
    def forward(self, x):
      x = self.layer1(x)
      x = self.layer2(x)  
      x = torch.flatten(x, 1)
      x = self.dropout(x)
      x = self.classifier(x)
      return x

# %%
#--------------------------------------------------
#       Start Training & Evaluation
#--------------------------------------------------
net = HorNet() 
train_option = {}
train_option['lr'] = 0.002
train_option['epoch'] = 60
train_option['device'] = 'gpu'
trainModel(net, trainloader_small, train_option, testloader_small)
# Out:
# Epoch: 1 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.8616 | Average Loss: 2.8616
# Epoch: 1 | Iter:   20 | Time: 00:00:00 | Train Loss: 2.7089 | Average Loss: 3.4855
# Epoch: 1 | Iter:   40 | Time: 00:00:00 | Train Loss: 2.7013 | Average Loss: 3.1113
# Epoch: 1 | Iter:   60 | Time: 00:00:00 | Train Loss: 2.6393 | Average Loss: 2.9663
# Accuracy: 0.156250 | Time: 00:00:00
# Epoch: 2 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.7103 | Average Loss: 2.9073
# Epoch: 2 | Iter:   20 | Time: 00:00:00 | Train Loss: 2.5134 | Average Loss: 2.8415
# Epoch: 2 | Iter:   40 | Time: 00:00:01 | Train Loss: 2.5171 | Average Loss: 2.7921
# Epoch: 2 | Iter:   60 | Time: 00:00:01 | Train Loss: 2.2950 | Average Loss: 2.7389
# Accuracy: 0.226562 | Time: 00:00:00
# Epoch: 3 | Iter:    0 | Time: 00:00:01 | Train Loss: 2.4205 | Average Loss: 2.6952
# Epoch: 3 | Iter:   20 | Time: 00:00:01 | Train Loss: 1.9993 | Average Loss: 2.6368
# Epoch: 3 | Iter:   40 | Time: 00:00:01 | Train Loss: 1.9628 | Average Loss: 2.5823
# Epoch: 3 | Iter:   60 | Time: 00:00:01 | Train Loss: 1.6885 | Average Loss: 2.5333
# Accuracy: 0.341146 | Time: 00:00:00
# Epoch: 4 | Iter:    0 | Time: 00:00:01 | Train Loss: 2.1662 | Average Loss: 2.4964
# Epoch: 4 | Iter:   20 | Time: 00:00:02 | Train Loss: 1.7809 | Average Loss: 2.4543
# Epoch: 4 | Iter:   40 | Time: 00:00:02 | Train Loss: 1.7224 | Average Loss: 2.4153
# Epoch: 4 | Iter:   60 | Time: 00:00:02 | Train Loss: 1.4494 | Average Loss: 2.3774
# Accuracy: 0.401042 | Time: 00:00:00
# Epoch: 5 | Iter:    0 | Time: 00:00:02 | Train Loss: 1.9732 | Average Loss: 2.3481
# Epoch: 5 | Iter:   20 | Time: 00:00:02 | Train Loss: 1.6322 | Average Loss: 2.3160
# Epoch: 5 | Iter:   40 | Time: 00:00:02 | Train Loss: 1.5831 | Average Loss: 2.2852
# Epoch: 5 | Iter:   60 | Time: 00:00:02 | Train Loss: 1.3239 | Average Loss: 2.2540
# Accuracy: 0.445312 | Time: 00:00:00
# Epoch: 6 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.7884 | Average Loss: 2.2288
# Epoch: 6 | Iter:   20 | Time: 00:00:03 | Train Loss: 1.4881 | Average Loss: 2.2000
# Epoch: 6 | Iter:   40 | Time: 00:00:03 | Train Loss: 1.3577 | Average Loss: 2.1687
# Epoch: 6 | Iter:   60 | Time: 00:00:03 | Train Loss: 1.0203 | Average Loss: 2.1357
# Accuracy: 0.515625 | Time: 00:00:00
# Epoch: 7 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.5162 | Average Loss: 2.1094
# Epoch: 7 | Iter:   20 | Time: 00:00:03 | Train Loss: 1.2868 | Average Loss: 2.0778
# Epoch: 7 | Iter:   40 | Time: 00:00:04 | Train Loss: 1.0974 | Average Loss: 2.0435
# Epoch: 7 | Iter:   60 | Time: 00:00:04 | Train Loss: 0.9225 | Average Loss: 2.0109
# Accuracy: 0.565104 | Time: 00:00:00
# Epoch: 8 | Iter:    0 | Time: 00:00:04 | Train Loss: 1.3746 | Average Loss: 1.9865
# Epoch: 8 | Iter:   20 | Time: 00:00:04 | Train Loss: 1.0414 | Average Loss: 1.9570
# Epoch: 8 | Iter:   40 | Time: 00:00:04 | Train Loss: 0.9172 | Average Loss: 1.9251
# Epoch: 8 | Iter:   60 | Time: 00:00:04 | Train Loss: 0.7318 | Average Loss: 1.8957
# Accuracy: 0.596354 | Time: 00:00:00
# Epoch: 9 | Iter:    0 | Time: 00:00:04 | Train Loss: 1.1435 | Average Loss: 1.8735
# Epoch: 9 | Iter:   20 | Time: 00:00:05 | Train Loss: 0.8374 | Average Loss: 1.8468
# Epoch: 9 | Iter:   40 | Time: 00:00:05 | Train Loss: 0.7254 | Average Loss: 1.8177
# Epoch: 9 | Iter:   60 | Time: 00:00:05 | Train Loss: 0.5949 | Average Loss: 1.7913
# Accuracy: 0.609375 | Time: 00:00:00
# Epoch:10 | Iter:    0 | Time: 00:00:05 | Train Loss: 1.0250 | Average Loss: 1.7711
# Epoch:10 | Iter:   20 | Time: 00:00:05 | Train Loss: 0.7342 | Average Loss: 1.7466
# Epoch:10 | Iter:   40 | Time: 00:00:05 | Train Loss: 0.6568 | Average Loss: 1.7213
# Epoch:10 | Iter:   60 | Time: 00:00:06 | Train Loss: 0.5615 | Average Loss: 1.6973
# Accuracy: 0.643229 | Time: 00:00:00
# Epoch:11 | Iter:    0 | Time: 00:00:06 | Train Loss: 1.0076 | Average Loss: 1.6794
# Epoch:11 | Iter:   20 | Time: 00:00:06 | Train Loss: 0.6142 | Average Loss: 1.6574
# Epoch:11 | Iter:   40 | Time: 00:00:06 | Train Loss: 0.6219 | Average Loss: 1.6346
# Epoch:11 | Iter:   60 | Time: 00:00:06 | Train Loss: 0.4662 | Average Loss: 1.6131
# Accuracy: 0.570312 | Time: 00:00:00
# Epoch:12 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.8318 | Average Loss: 1.5970
# Epoch:12 | Iter:   20 | Time: 00:00:06 | Train Loss: 0.5975 | Average Loss: 1.5773
# Epoch:12 | Iter:   40 | Time: 00:00:07 | Train Loss: 0.4978 | Average Loss: 1.5563
# Epoch:12 | Iter:   60 | Time: 00:00:07 | Train Loss: 0.4699 | Average Loss: 1.5362
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:13 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.6451 | Average Loss: 1.5214
# Epoch:13 | Iter:   20 | Time: 00:00:07 | Train Loss: 0.5070 | Average Loss: 1.5033
# Epoch:13 | Iter:   40 | Time: 00:00:07 | Train Loss: 0.5075 | Average Loss: 1.4844
# Epoch:13 | Iter:   60 | Time: 00:00:07 | Train Loss: 0.3644 | Average Loss: 1.4659
# Accuracy: 0.611979 | Time: 00:00:00
# Epoch:14 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.6535 | Average Loss: 1.4519
# Epoch:14 | Iter:   20 | Time: 00:00:08 | Train Loss: 0.4870 | Average Loss: 1.4350
# Epoch:14 | Iter:   40 | Time: 00:00:08 | Train Loss: 0.4567 | Average Loss: 1.4173
# Epoch:14 | Iter:   60 | Time: 00:00:08 | Train Loss: 0.3984 | Average Loss: 1.4006
# Accuracy: 0.604167 | Time: 00:00:00
# Epoch:15 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.5832 | Average Loss: 1.3880
# Epoch:15 | Iter:   20 | Time: 00:00:08 | Train Loss: 0.3613 | Average Loss: 1.3723
# Epoch:15 | Iter:   40 | Time: 00:00:08 | Train Loss: 0.4091 | Average Loss: 1.3560
# Epoch:15 | Iter:   60 | Time: 00:00:09 | Train Loss: 0.3301 | Average Loss: 1.3402
# Accuracy: 0.596354 | Time: 00:00:00
# Epoch:16 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.5726 | Average Loss: 1.3290
# Epoch:16 | Iter:   20 | Time: 00:00:09 | Train Loss: 0.3021 | Average Loss: 1.3141
# Epoch:16 | Iter:   40 | Time: 00:00:09 | Train Loss: 0.3043 | Average Loss: 1.2991
# Epoch:16 | Iter:   60 | Time: 00:00:09 | Train Loss: 0.3640 | Average Loss: 1.2844
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:17 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.4884 | Average Loss: 1.2738
# Epoch:17 | Iter:   20 | Time: 00:00:09 | Train Loss: 0.2695 | Average Loss: 1.2600
# Epoch:17 | Iter:   40 | Time: 00:00:10 | Train Loss: 0.2576 | Average Loss: 1.2462
# Epoch:17 | Iter:   60 | Time: 00:00:10 | Train Loss: 0.3094 | Average Loss: 1.2328
# Accuracy: 0.614583 | Time: 00:00:00
# Epoch:18 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.4455 | Average Loss: 1.2229
# Epoch:18 | Iter:   20 | Time: 00:00:10 | Train Loss: 0.2630 | Average Loss: 1.2105
# Epoch:18 | Iter:   40 | Time: 00:00:10 | Train Loss: 0.3339 | Average Loss: 1.1977
# Epoch:18 | Iter:   60 | Time: 00:00:10 | Train Loss: 0.2804 | Average Loss: 1.1850
# Accuracy: 0.648438 | Time: 00:00:00
# Epoch:19 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.4251 | Average Loss: 1.1758
# Epoch:19 | Iter:   20 | Time: 00:00:11 | Train Loss: 0.2846 | Average Loss: 1.1638
# Epoch:19 | Iter:   40 | Time: 00:00:11 | Train Loss: 0.2697 | Average Loss: 1.1515
# Epoch:19 | Iter:   60 | Time: 00:00:11 | Train Loss: 0.2460 | Average Loss: 1.1397
# Accuracy: 0.627604 | Time: 00:00:00
# Epoch:20 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.4075 | Average Loss: 1.1310
# Epoch:20 | Iter:   20 | Time: 00:00:11 | Train Loss: 0.2453 | Average Loss: 1.1196
# Epoch:20 | Iter:   40 | Time: 00:00:11 | Train Loss: 0.2374 | Average Loss: 1.1089
# Epoch:20 | Iter:   60 | Time: 00:00:12 | Train Loss: 0.2080 | Average Loss: 1.0978
# Accuracy: 0.638021 | Time: 00:00:00
# Epoch:21 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.3285 | Average Loss: 1.0896
# Epoch:21 | Iter:   20 | Time: 00:00:12 | Train Loss: 0.2563 | Average Loss: 1.0791
# Epoch:21 | Iter:   40 | Time: 00:00:12 | Train Loss: 0.2480 | Average Loss: 1.0689
# Epoch:21 | Iter:   60 | Time: 00:00:12 | Train Loss: 0.1459 | Average Loss: 1.0586
# Accuracy: 0.645833 | Time: 00:00:00
# Epoch:22 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.1742 | Average Loss: 1.0509
# Epoch:22 | Iter:   20 | Time: 00:00:13 | Train Loss: 0.2031 | Average Loss: 1.0412
# Epoch:22 | Iter:   40 | Time: 00:00:13 | Train Loss: 0.2359 | Average Loss: 1.0313
# Epoch:22 | Iter:   60 | Time: 00:00:13 | Train Loss: 0.2515 | Average Loss: 1.0218
# Accuracy: 0.648438 | Time: 00:00:00
# Epoch:23 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.2557 | Average Loss: 1.0146
# Epoch:23 | Iter:   20 | Time: 00:00:13 | Train Loss: 0.1999 | Average Loss: 1.0055
# Epoch:23 | Iter:   40 | Time: 00:00:13 | Train Loss: 0.1361 | Average Loss: 0.9962
# Epoch:23 | Iter:   60 | Time: 00:00:13 | Train Loss: 0.1799 | Average Loss: 0.9871
# Accuracy: 0.653646 | Time: 00:00:00
# Epoch:24 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.2011 | Average Loss: 0.9805
# Epoch:24 | Iter:   20 | Time: 00:00:14 | Train Loss: 0.1324 | Average Loss: 0.9717
# Epoch:24 | Iter:   40 | Time: 00:00:14 | Train Loss: 0.1623 | Average Loss: 0.9631
# Epoch:24 | Iter:   60 | Time: 00:00:14 | Train Loss: 0.1857 | Average Loss: 0.9545
# Accuracy: 0.661458 | Time: 00:00:00
# Epoch:25 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.2072 | Average Loss: 0.9483
# Epoch:25 | Iter:   20 | Time: 00:00:14 | Train Loss: 0.1341 | Average Loss: 0.9400
# Epoch:25 | Iter:   40 | Time: 00:00:15 | Train Loss: 0.1730 | Average Loss: 0.9318
# Epoch:25 | Iter:   60 | Time: 00:00:15 | Train Loss: 0.1046 | Average Loss: 0.9239
# Accuracy: 0.648438 | Time: 00:00:00
# Epoch:26 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.1663 | Average Loss: 0.9180
# Epoch:26 | Iter:   20 | Time: 00:00:15 | Train Loss: 0.1125 | Average Loss: 0.9103
# Epoch:26 | Iter:   40 | Time: 00:00:15 | Train Loss: 0.1009 | Average Loss: 0.9027
# Epoch:26 | Iter:   60 | Time: 00:00:15 | Train Loss: 0.1098 | Average Loss: 0.8951
# Accuracy: 0.653646 | Time: 00:00:00
# Epoch:27 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.2209 | Average Loss: 0.8897
# Epoch:27 | Iter:   20 | Time: 00:00:16 | Train Loss: 0.1403 | Average Loss: 0.8826
# Epoch:27 | Iter:   40 | Time: 00:00:16 | Train Loss: 0.1428 | Average Loss: 0.8753
# Epoch:27 | Iter:   60 | Time: 00:00:16 | Train Loss: 0.1094 | Average Loss: 0.8681
# Accuracy: 0.653646 | Time: 00:00:00
# Epoch:28 | Iter:    0 | Time: 00:00:16 | Train Loss: 0.2709 | Average Loss: 0.8629
# Epoch:28 | Iter:   20 | Time: 00:00:16 | Train Loss: 0.0989 | Average Loss: 0.8562
# Epoch:28 | Iter:   40 | Time: 00:00:16 | Train Loss: 0.1327 | Average Loss: 0.8494
# Epoch:28 | Iter:   60 | Time: 00:00:17 | Train Loss: 0.0821 | Average Loss: 0.8426
# Accuracy: 0.635417 | Time: 00:00:00
# Epoch:29 | Iter:    0 | Time: 00:00:17 | Train Loss: 0.1336 | Average Loss: 0.8375
# Epoch:29 | Iter:   20 | Time: 00:00:17 | Train Loss: 0.1324 | Average Loss: 0.8311
# Epoch:29 | Iter:   40 | Time: 00:00:17 | Train Loss: 0.0944 | Average Loss: 0.8245
# Epoch:29 | Iter:   60 | Time: 00:00:17 | Train Loss: 0.0683 | Average Loss: 0.8180
# Accuracy: 0.643229 | Time: 00:00:00
# Epoch:30 | Iter:    0 | Time: 00:00:17 | Train Loss: 0.1565 | Average Loss: 0.8132
# Epoch:30 | Iter:   20 | Time: 00:00:17 | Train Loss: 0.0593 | Average Loss: 0.8069
# Epoch:30 | Iter:   40 | Time: 00:00:18 | Train Loss: 0.1050 | Average Loss: 0.8006
# Epoch:30 | Iter:   60 | Time: 00:00:18 | Train Loss: 0.0763 | Average Loss: 0.7945
# Accuracy: 0.658854 | Time: 00:00:00
# Epoch:31 | Iter:    0 | Time: 00:00:18 | Train Loss: 0.1370 | Average Loss: 0.7899
# Epoch:31 | Iter:   20 | Time: 00:00:18 | Train Loss: 0.1606 | Average Loss: 0.7840
# Epoch:31 | Iter:   40 | Time: 00:00:18 | Train Loss: 0.1388 | Average Loss: 0.7782
# Epoch:31 | Iter:   60 | Time: 00:00:18 | Train Loss: 0.0368 | Average Loss: 0.7725
# Accuracy: 0.635417 | Time: 00:00:00
# Epoch:32 | Iter:    0 | Time: 00:00:19 | Train Loss: 0.0989 | Average Loss: 0.7683
# Epoch:32 | Iter:   20 | Time: 00:00:19 | Train Loss: 0.1179 | Average Loss: 0.7627
# Epoch:32 | Iter:   40 | Time: 00:00:19 | Train Loss: 0.1215 | Average Loss: 0.7571
# Epoch:32 | Iter:   60 | Time: 00:00:19 | Train Loss: 0.1097 | Average Loss: 0.7516
# Accuracy: 0.645833 | Time: 00:00:00
# Epoch:33 | Iter:    0 | Time: 00:00:19 | Train Loss: 0.1247 | Average Loss: 0.7475
# Epoch:33 | Iter:   20 | Time: 00:00:19 | Train Loss: 0.0491 | Average Loss: 0.7421
# Epoch:33 | Iter:   40 | Time: 00:00:19 | Train Loss: 0.0499 | Average Loss: 0.7368
# Epoch:33 | Iter:   60 | Time: 00:00:20 | Train Loss: 0.0733 | Average Loss: 0.7314
# Accuracy: 0.632812 | Time: 00:00:00
# Epoch:34 | Iter:    0 | Time: 00:00:20 | Train Loss: 0.1440 | Average Loss: 0.7276
# Epoch:34 | Iter:   20 | Time: 00:00:20 | Train Loss: 0.1118 | Average Loss: 0.7225
# Epoch:34 | Iter:   40 | Time: 00:00:20 | Train Loss: 0.0866 | Average Loss: 0.7175
# Epoch:34 | Iter:   60 | Time: 00:00:20 | Train Loss: 0.0710 | Average Loss: 0.7124
# Accuracy: 0.630208 | Time: 00:00:00
# Epoch:35 | Iter:    0 | Time: 00:00:20 | Train Loss: 0.1113 | Average Loss: 0.7087
# Epoch:35 | Iter:   20 | Time: 00:00:21 | Train Loss: 0.0516 | Average Loss: 0.7038
# Epoch:35 | Iter:   40 | Time: 00:00:21 | Train Loss: 0.1204 | Average Loss: 0.6991
# Epoch:35 | Iter:   60 | Time: 00:00:21 | Train Loss: 0.0721 | Average Loss: 0.6944
# Accuracy: 0.630208 | Time: 00:00:00
# Epoch:36 | Iter:    0 | Time: 00:00:21 | Train Loss: 0.1312 | Average Loss: 0.6908
# Epoch:36 | Iter:   20 | Time: 00:00:21 | Train Loss: 0.0323 | Average Loss: 0.6863
# Epoch:36 | Iter:   40 | Time: 00:00:21 | Train Loss: 0.0510 | Average Loss: 0.6817
# Epoch:36 | Iter:   60 | Time: 00:00:21 | Train Loss: 0.0561 | Average Loss: 0.6771
# Accuracy: 0.632812 | Time: 00:00:00
# Epoch:37 | Iter:    0 | Time: 00:00:22 | Train Loss: 0.0823 | Average Loss: 0.6738
# Epoch:37 | Iter:   20 | Time: 00:00:22 | Train Loss: 0.0372 | Average Loss: 0.6694
# Epoch:37 | Iter:   40 | Time: 00:00:22 | Train Loss: 0.0704 | Average Loss: 0.6652
# Epoch:37 | Iter:   60 | Time: 00:00:22 | Train Loss: 0.1294 | Average Loss: 0.6610
# Accuracy: 0.635417 | Time: 00:00:00
# Epoch:38 | Iter:    0 | Time: 00:00:22 | Train Loss: 0.0597 | Average Loss: 0.6577
# Epoch:38 | Iter:   20 | Time: 00:00:22 | Train Loss: 0.0518 | Average Loss: 0.6534
# Epoch:38 | Iter:   40 | Time: 00:00:23 | Train Loss: 0.0653 | Average Loss: 0.6493
# Epoch:38 | Iter:   60 | Time: 00:00:23 | Train Loss: 0.0353 | Average Loss: 0.6451
# Accuracy: 0.635417 | Time: 00:00:00
# Epoch:39 | Iter:    0 | Time: 00:00:23 | Train Loss: 0.0562 | Average Loss: 0.6421
# Epoch:39 | Iter:   20 | Time: 00:00:23 | Train Loss: 0.0367 | Average Loss: 0.6380
# Epoch:39 | Iter:   40 | Time: 00:00:23 | Train Loss: 0.0548 | Average Loss: 0.6340
# Epoch:39 | Iter:   60 | Time: 00:00:23 | Train Loss: 0.0989 | Average Loss: 0.6300
# Accuracy: 0.658854 | Time: 00:00:00
# Epoch:40 | Iter:    0 | Time: 00:00:23 | Train Loss: 0.0299 | Average Loss: 0.6271
# Epoch:40 | Iter:   20 | Time: 00:00:24 | Train Loss: 0.0389 | Average Loss: 0.6232
# Epoch:40 | Iter:   40 | Time: 00:00:24 | Train Loss: 0.0322 | Average Loss: 0.6193
# Epoch:40 | Iter:   60 | Time: 00:00:24 | Train Loss: 0.0537 | Average Loss: 0.6156
# Accuracy: 0.635417 | Time: 00:00:00
# Epoch:41 | Iter:    0 | Time: 00:00:24 | Train Loss: 0.0651 | Average Loss: 0.6128
# Epoch:41 | Iter:   20 | Time: 00:00:24 | Train Loss: 0.0326 | Average Loss: 0.6091
# Epoch:41 | Iter:   40 | Time: 00:00:24 | Train Loss: 0.0241 | Average Loss: 0.6054
# Epoch:41 | Iter:   60 | Time: 00:00:25 | Train Loss: 0.0373 | Average Loss: 0.6018
# Accuracy: 0.632812 | Time: 00:00:00
# Epoch:42 | Iter:    0 | Time: 00:00:25 | Train Loss: 0.0613 | Average Loss: 0.5991
# Epoch:42 | Iter:   20 | Time: 00:00:25 | Train Loss: 0.0265 | Average Loss: 0.5955
# Epoch:42 | Iter:   40 | Time: 00:00:25 | Train Loss: 0.0203 | Average Loss: 0.5920
# Epoch:42 | Iter:   60 | Time: 00:00:25 | Train Loss: 0.0334 | Average Loss: 0.5885
# Accuracy: 0.645833 | Time: 00:00:00
# Epoch:43 | Iter:    0 | Time: 00:00:25 | Train Loss: 0.0470 | Average Loss: 0.5859
# Epoch:43 | Iter:   20 | Time: 00:00:25 | Train Loss: 0.0319 | Average Loss: 0.5826
# Epoch:43 | Iter:   40 | Time: 00:00:26 | Train Loss: 0.0283 | Average Loss: 0.5792
# Epoch:43 | Iter:   60 | Time: 00:00:26 | Train Loss: 0.0697 | Average Loss: 0.5759
# Accuracy: 0.632812 | Time: 00:00:00
# Epoch:44 | Iter:    0 | Time: 00:00:26 | Train Loss: 0.0441 | Average Loss: 0.5734
# Epoch:44 | Iter:   20 | Time: 00:00:26 | Train Loss: 0.0613 | Average Loss: 0.5701
# Epoch:44 | Iter:   40 | Time: 00:00:26 | Train Loss: 0.0277 | Average Loss: 0.5669
# Epoch:44 | Iter:   60 | Time: 00:00:26 | Train Loss: 0.0253 | Average Loss: 0.5637
# Accuracy: 0.635417 | Time: 00:00:00
# Epoch:45 | Iter:    0 | Time: 00:00:27 | Train Loss: 0.0342 | Average Loss: 0.5613
# Epoch:45 | Iter:   20 | Time: 00:00:27 | Train Loss: 0.0125 | Average Loss: 0.5582
# Epoch:45 | Iter:   40 | Time: 00:00:27 | Train Loss: 0.0508 | Average Loss: 0.5551
# Epoch:45 | Iter:   60 | Time: 00:00:27 | Train Loss: 0.0418 | Average Loss: 0.5520
# Accuracy: 0.643229 | Time: 00:00:00
# Epoch:46 | Iter:    0 | Time: 00:00:27 | Train Loss: 0.0312 | Average Loss: 0.5497
# Epoch:46 | Iter:   20 | Time: 00:00:27 | Train Loss: 0.0365 | Average Loss: 0.5467
# Epoch:46 | Iter:   40 | Time: 00:00:27 | Train Loss: 0.0331 | Average Loss: 0.5438
# Epoch:46 | Iter:   60 | Time: 00:00:28 | Train Loss: 0.0164 | Average Loss: 0.5408
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:47 | Iter:    0 | Time: 00:00:28 | Train Loss: 0.0337 | Average Loss: 0.5386
# Epoch:47 | Iter:   20 | Time: 00:00:28 | Train Loss: 0.0182 | Average Loss: 0.5357
# Epoch:47 | Iter:   40 | Time: 00:00:28 | Train Loss: 0.0436 | Average Loss: 0.5329
# Epoch:47 | Iter:   60 | Time: 00:00:28 | Train Loss: 0.0339 | Average Loss: 0.5301
# Accuracy: 0.661458 | Time: 00:00:00
# Epoch:48 | Iter:    0 | Time: 00:00:28 | Train Loss: 0.0225 | Average Loss: 0.5279
# Epoch:48 | Iter:   20 | Time: 00:00:29 | Train Loss: 0.0319 | Average Loss: 0.5251
# Epoch:48 | Iter:   40 | Time: 00:00:29 | Train Loss: 0.0299 | Average Loss: 0.5224
# Epoch:48 | Iter:   60 | Time: 00:00:29 | Train Loss: 0.0443 | Average Loss: 0.5197
# Accuracy: 0.653646 | Time: 00:00:00
# Epoch:49 | Iter:    0 | Time: 00:00:29 | Train Loss: 0.0177 | Average Loss: 0.5176
# Epoch:49 | Iter:   20 | Time: 00:00:29 | Train Loss: 0.0337 | Average Loss: 0.5150
# Epoch:49 | Iter:   40 | Time: 00:00:29 | Train Loss: 0.0136 | Average Loss: 0.5123
# Epoch:49 | Iter:   60 | Time: 00:00:30 | Train Loss: 0.0091 | Average Loss: 0.5096
# Accuracy: 0.638021 | Time: 00:00:00
# Epoch:50 | Iter:    0 | Time: 00:00:30 | Train Loss: 0.0166 | Average Loss: 0.5077
# Epoch:50 | Iter:   20 | Time: 00:00:30 | Train Loss: 0.0164 | Average Loss: 0.5052
# Epoch:50 | Iter:   40 | Time: 00:00:30 | Train Loss: 0.0252 | Average Loss: 0.5026
# Epoch:50 | Iter:   60 | Time: 00:00:30 | Train Loss: 0.0422 | Average Loss: 0.5001
# Accuracy: 0.658854 | Time: 00:00:00
# Epoch:51 | Iter:    0 | Time: 00:00:30 | Train Loss: 0.0537 | Average Loss: 0.4982
# Epoch:51 | Iter:   20 | Time: 00:00:30 | Train Loss: 0.0488 | Average Loss: 0.4958
# Epoch:51 | Iter:   40 | Time: 00:00:31 | Train Loss: 0.0289 | Average Loss: 0.4933
# Epoch:51 | Iter:   60 | Time: 00:00:31 | Train Loss: 0.0408 | Average Loss: 0.4909
# Accuracy: 0.664062 | Time: 00:00:00
# Epoch:52 | Iter:    0 | Time: 00:00:31 | Train Loss: 0.0229 | Average Loss: 0.4890
# Epoch:52 | Iter:   20 | Time: 00:00:31 | Train Loss: 0.0250 | Average Loss: 0.4867
# Epoch:52 | Iter:   40 | Time: 00:00:31 | Train Loss: 0.0140 | Average Loss: 0.4843
# Epoch:52 | Iter:   60 | Time: 00:00:31 | Train Loss: 0.0179 | Average Loss: 0.4819
# Accuracy: 0.651042 | Time: 00:00:00
# Epoch:53 | Iter:    0 | Time: 00:00:32 | Train Loss: 0.0169 | Average Loss: 0.4802
# Epoch:53 | Iter:   20 | Time: 00:00:32 | Train Loss: 0.0160 | Average Loss: 0.4779
# Epoch:53 | Iter:   40 | Time: 00:00:32 | Train Loss: 0.0308 | Average Loss: 0.4756
# Epoch:53 | Iter:   60 | Time: 00:00:32 | Train Loss: 0.0157 | Average Loss: 0.4733
# Accuracy: 0.632812 | Time: 00:00:00
# Epoch:54 | Iter:    0 | Time: 00:00:32 | Train Loss: 0.0148 | Average Loss: 0.4717
# Epoch:54 | Iter:   20 | Time: 00:00:32 | Train Loss: 0.0407 | Average Loss: 0.4695
# Epoch:54 | Iter:   40 | Time: 00:00:32 | Train Loss: 0.0346 | Average Loss: 0.4673
# Epoch:54 | Iter:   60 | Time: 00:00:33 | Train Loss: 0.0248 | Average Loss: 0.4652
# Accuracy: 0.640625 | Time: 00:00:00
# Epoch:55 | Iter:    0 | Time: 00:00:33 | Train Loss: 0.0864 | Average Loss: 0.4637
# Epoch:55 | Iter:   20 | Time: 00:00:33 | Train Loss: 0.0178 | Average Loss: 0.4616
# Epoch:55 | Iter:   40 | Time: 00:00:33 | Train Loss: 0.0209 | Average Loss: 0.4595
# Epoch:55 | Iter:   60 | Time: 00:00:33 | Train Loss: 0.0279 | Average Loss: 0.4575
# Accuracy: 0.653646 | Time: 00:00:00
# Epoch:56 | Iter:    0 | Time: 00:00:33 | Train Loss: 0.0210 | Average Loss: 0.4559
# Epoch:56 | Iter:   20 | Time: 00:00:34 | Train Loss: 0.0234 | Average Loss: 0.4539
# Epoch:56 | Iter:   40 | Time: 00:00:34 | Train Loss: 0.0144 | Average Loss: 0.4518
# Epoch:56 | Iter:   60 | Time: 00:00:34 | Train Loss: 0.0260 | Average Loss: 0.4499
# Accuracy: 0.648438 | Time: 00:00:00
# Epoch:57 | Iter:    0 | Time: 00:00:34 | Train Loss: 0.0242 | Average Loss: 0.4484
# Epoch:57 | Iter:   20 | Time: 00:00:34 | Train Loss: 0.0153 | Average Loss: 0.4464
# Epoch:57 | Iter:   40 | Time: 00:00:34 | Train Loss: 0.0614 | Average Loss: 0.4445
# Epoch:57 | Iter:   60 | Time: 00:00:34 | Train Loss: 0.0307 | Average Loss: 0.4425
# Accuracy: 0.653646 | Time: 00:00:00
# Epoch:58 | Iter:    0 | Time: 00:00:35 | Train Loss: 0.0122 | Average Loss: 0.4410
# Epoch:58 | Iter:   20 | Time: 00:00:35 | Train Loss: 0.0206 | Average Loss: 0.4391
# Epoch:58 | Iter:   40 | Time: 00:00:35 | Train Loss: 0.0242 | Average Loss: 0.4372
# Epoch:58 | Iter:   60 | Time: 00:00:35 | Train Loss: 0.0134 | Average Loss: 0.4353
# Accuracy: 0.669271 | Time: 00:00:00
# Epoch:59 | Iter:    0 | Time: 00:00:35 | Train Loss: 0.0216 | Average Loss: 0.4339
# Epoch:59 | Iter:   20 | Time: 00:00:35 | Train Loss: 0.0145 | Average Loss: 0.4320
# Epoch:59 | Iter:   40 | Time: 00:00:36 | Train Loss: 0.0180 | Average Loss: 0.4302
# Epoch:59 | Iter:   60 | Time: 00:00:36 | Train Loss: 0.0422 | Average Loss: 0.4283
# Accuracy: 0.632812 | Time: 00:00:00
# Epoch:60 | Iter:    0 | Time: 00:00:36 | Train Loss: 0.0102 | Average Loss: 0.4270
# Epoch:60 | Iter:   20 | Time: 00:00:36 | Train Loss: 0.0133 | Average Loss: 0.4252
# Epoch:60 | Iter:   40 | Time: 00:00:36 | Train Loss: 0.0151 | Average Loss: 0.4234
# Epoch:60 | Iter:   60 | Time: 00:00:36 | Train Loss: 0.0432 | Average Loss: 0.4216
# Accuracy: 0.661458 | Time: 00:00:00

# %% [markdown]
# **Answer**:
#
# Technique 1: Network architecture modification
#
# Data augmentation: No augmentation
#
# Data normalization: First we calculated the mean and then subtracted from the image, which resulted in zero-centered image
#
# Layer 1: Convolution layer with 16 output channels, followed by ReLU activation and MaxPooling layer
#
# Layer 2: Convolution layer with 128 output channels, followed by Sigmoid activation and MaxPooling layer
#
# Layer 3: NN layer with 4608 input node and 16 output nodes. Dropout with p=0.25 was also added before this
#
# Accuracy on test set: **0.669271**
#
# Accuracy increases/decreases: Increase

# %% [markdown]
# ### Technique 2

# %%
#--------------------------------------------------
#    Load Training Data and Testing Data
#--------------------------------------------------
# load data into size (64, 64)
img_size = (64, 64)

batch_size = 64         # training sample number per batch

# load training dataset

trainloader_small = list(load_dataset('./data/train/', img_size, batch_size=batch_size, shuffle=True, augment=False, zero_centered=True))
train_num = len(trainloader_small)

print("Finish loading %d minibatches (batch_size=%d) of training samples." % (train_num, batch_size))

# load testing dataset

testloader_small = list(load_dataset('./data/test/', img_size, num_per_class=50, batch_size=batch_size, zero_centered=True))

test_num = len(testloader_small)

print("Finish loading %d minibatches (batch_size=%d) of testing samples." % (test_num, batch_size))
# Out:
# Loading images from class: 0
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:43: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 37 minibatches (batch_size=64) of training samples.
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 6 minibatches (batch_size=64) of testing samples.

# %%
#--------------------------------------------------
#       Define Network Architecture
#--------------------------------------------------
class HorNet(nn.Module):
    def __init__(self):
      super(HorNet,self).__init__()  
           
      self.layer1 = torch.nn.Sequential(
        nn.Conv2d(1, 64, 3),
        nn.BatchNorm2d(64),
        nn.Tanh(),
        nn.MaxPool2d(4, stride=4), 
      )
      self.layer2 = torch.nn.Sequential(
        nn.Conv2d(64, 128, 3),
        nn.Sigmoid(),
        nn.MaxPool2d(2, stride=2), 
      )
      
      self.classifier1 = nn.Sequential(
         nn.Linear(4608, 1024), 
         nn.BatchNorm1d(1024),
         nn.LeakyReLU()
      )
      self.classifier2 = nn.Sequential(
         nn.Linear(1024, 16),
         nn.BatchNorm1d(16),
         nn.Sigmoid()
      )

      self.dropout = nn.Dropout(0.5)
      
    def forward(self, x):
      x = self.layer1(x)
      x = self.layer2(x)  
      x = torch.flatten(x, 1)
      x = self.dropout(x)
      x = self.classifier1(x)
      x = self.classifier2(x)
      return x

# %%
#--------------------------------------------------
#       Start Training & Evaluation
#--------------------------------------------------
net = HorNet() 
train_option = {}
train_option['lr'] = 0.002
train_option['epoch'] = 60
train_option['device'] = 'gpu'
trainModel(net, trainloader_small, train_option, testloader_small)
# Out:
# Epoch: 1 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.8015 | Average Loss: 2.8015
# Epoch: 1 | Iter:   20 | Time: 00:00:00 | Train Loss: 2.6417 | Average Loss: 2.6768
# Epoch: 1 | Iter:   40 | Time: 00:00:00 | Train Loss: 2.5648 | Average Loss: 2.6413
# Epoch: 1 | Iter:   60 | Time: 00:00:00 | Train Loss: 2.5413 | Average Loss: 2.6206
# Accuracy: 0.346354 | Time: 00:00:00
# Epoch: 2 | Iter:    0 | Time: 00:00:01 | Train Loss: 2.5513 | Average Loss: 2.6063
# Epoch: 2 | Iter:   20 | Time: 00:00:01 | Train Loss: 2.4973 | Average Loss: 2.5909
# Epoch: 2 | Iter:   40 | Time: 00:00:01 | Train Loss: 2.4628 | Average Loss: 2.5758
# Epoch: 2 | Iter:   60 | Time: 00:00:01 | Train Loss: 2.4301 | Average Loss: 2.5623
# Accuracy: 0.476562 | Time: 00:00:00
# Epoch: 3 | Iter:    0 | Time: 00:00:02 | Train Loss: 2.4867 | Average Loss: 2.5521
# Epoch: 3 | Iter:   20 | Time: 00:00:02 | Train Loss: 2.4115 | Average Loss: 2.5400
# Epoch: 3 | Iter:   40 | Time: 00:00:02 | Train Loss: 2.4198 | Average Loss: 2.5283
# Epoch: 3 | Iter:   60 | Time: 00:00:02 | Train Loss: 2.3542 | Average Loss: 2.5167
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch: 4 | Iter:    0 | Time: 00:00:03 | Train Loss: 2.4081 | Average Loss: 2.5082
# Epoch: 4 | Iter:   20 | Time: 00:00:03 | Train Loss: 2.3382 | Average Loss: 2.4981
# Epoch: 4 | Iter:   40 | Time: 00:00:03 | Train Loss: 2.3547 | Average Loss: 2.4880
# Epoch: 4 | Iter:   60 | Time: 00:00:03 | Train Loss: 2.2897 | Average Loss: 2.4783
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch: 5 | Iter:    0 | Time: 00:00:04 | Train Loss: 2.3506 | Average Loss: 2.4712
# Epoch: 5 | Iter:   20 | Time: 00:00:04 | Train Loss: 2.3019 | Average Loss: 2.4626
# Epoch: 5 | Iter:   40 | Time: 00:00:04 | Train Loss: 2.2957 | Average Loss: 2.4538
# Epoch: 5 | Iter:   60 | Time: 00:00:04 | Train Loss: 2.2657 | Average Loss: 2.4454
# Accuracy: 0.601562 | Time: 00:00:00
# Epoch: 6 | Iter:    0 | Time: 00:00:05 | Train Loss: 2.3029 | Average Loss: 2.4393
# Epoch: 6 | Iter:   20 | Time: 00:00:05 | Train Loss: 2.2466 | Average Loss: 2.4315
# Epoch: 6 | Iter:   40 | Time: 00:00:05 | Train Loss: 2.2595 | Average Loss: 2.4235
# Epoch: 6 | Iter:   60 | Time: 00:00:05 | Train Loss: 2.2276 | Average Loss: 2.4158
# Accuracy: 0.645833 | Time: 00:00:00
# Epoch: 7 | Iter:    0 | Time: 00:00:06 | Train Loss: 2.2651 | Average Loss: 2.4104
# Epoch: 7 | Iter:   20 | Time: 00:00:06 | Train Loss: 2.2118 | Average Loss: 2.4034
# Epoch: 7 | Iter:   40 | Time: 00:00:06 | Train Loss: 2.2221 | Average Loss: 2.3964
# Epoch: 7 | Iter:   60 | Time: 00:00:06 | Train Loss: 2.1937 | Average Loss: 2.3896
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch: 8 | Iter:    0 | Time: 00:00:07 | Train Loss: 2.2373 | Average Loss: 2.3847
# Epoch: 8 | Iter:   20 | Time: 00:00:07 | Train Loss: 2.2025 | Average Loss: 2.3784
# Epoch: 8 | Iter:   40 | Time: 00:00:07 | Train Loss: 2.1954 | Average Loss: 2.3721
# Epoch: 8 | Iter:   60 | Time: 00:00:07 | Train Loss: 2.1708 | Average Loss: 2.3658
# Accuracy: 0.653646 | Time: 00:00:00
# Epoch: 9 | Iter:    0 | Time: 00:00:08 | Train Loss: 2.2049 | Average Loss: 2.3612
# Epoch: 9 | Iter:   20 | Time: 00:00:08 | Train Loss: 2.1510 | Average Loss: 2.3555
# Epoch: 9 | Iter:   40 | Time: 00:00:08 | Train Loss: 2.1665 | Average Loss: 2.3498
# Epoch: 9 | Iter:   60 | Time: 00:00:08 | Train Loss: 2.1447 | Average Loss: 2.3440
# Accuracy: 0.671875 | Time: 00:00:00
# Epoch:10 | Iter:    0 | Time: 00:00:09 | Train Loss: 2.1646 | Average Loss: 2.3397
# Epoch:10 | Iter:   20 | Time: 00:00:09 | Train Loss: 2.1304 | Average Loss: 2.3345
# Epoch:10 | Iter:   40 | Time: 00:00:09 | Train Loss: 2.1413 | Average Loss: 2.3291
# Epoch:10 | Iter:   60 | Time: 00:00:09 | Train Loss: 2.1163 | Average Loss: 2.3239
# Accuracy: 0.664062 | Time: 00:00:00
# Epoch:11 | Iter:    0 | Time: 00:00:10 | Train Loss: 2.1306 | Average Loss: 2.3200
# Epoch:11 | Iter:   20 | Time: 00:00:10 | Train Loss: 2.1112 | Average Loss: 2.3150
# Epoch:11 | Iter:   40 | Time: 00:00:10 | Train Loss: 2.1067 | Average Loss: 2.3101
# Epoch:11 | Iter:   60 | Time: 00:00:10 | Train Loss: 2.1095 | Average Loss: 2.3052
# Accuracy: 0.674479 | Time: 00:00:00
# Epoch:12 | Iter:    0 | Time: 00:00:11 | Train Loss: 2.1150 | Average Loss: 2.3016
# Epoch:12 | Iter:   20 | Time: 00:00:11 | Train Loss: 2.0923 | Average Loss: 2.2971
# Epoch:12 | Iter:   40 | Time: 00:00:11 | Train Loss: 2.0844 | Average Loss: 2.2925
# Epoch:12 | Iter:   60 | Time: 00:00:11 | Train Loss: 2.0769 | Average Loss: 2.2880
# Accuracy: 0.679688 | Time: 00:00:00
# Epoch:13 | Iter:    0 | Time: 00:00:12 | Train Loss: 2.0948 | Average Loss: 2.2847
# Epoch:13 | Iter:   20 | Time: 00:00:12 | Train Loss: 2.0662 | Average Loss: 2.2805
# Epoch:13 | Iter:   40 | Time: 00:00:12 | Train Loss: 2.0717 | Average Loss: 2.2762
# Epoch:13 | Iter:   60 | Time: 00:00:12 | Train Loss: 2.0620 | Average Loss: 2.2720
# Accuracy: 0.674479 | Time: 00:00:00
# Epoch:14 | Iter:    0 | Time: 00:00:13 | Train Loss: 2.0792 | Average Loss: 2.2689
# Epoch:14 | Iter:   20 | Time: 00:00:13 | Train Loss: 2.0536 | Average Loss: 2.2648
# Epoch:14 | Iter:   40 | Time: 00:00:13 | Train Loss: 2.0642 | Average Loss: 2.2609
# Epoch:14 | Iter:   60 | Time: 00:00:13 | Train Loss: 2.0484 | Average Loss: 2.2570
# Accuracy: 0.697917 | Time: 00:00:00
# Epoch:15 | Iter:    0 | Time: 00:00:14 | Train Loss: 2.0610 | Average Loss: 2.2541
# Epoch:15 | Iter:   20 | Time: 00:00:14 | Train Loss: 2.0405 | Average Loss: 2.2504
# Epoch:15 | Iter:   40 | Time: 00:00:14 | Train Loss: 2.0341 | Average Loss: 2.2466
# Epoch:15 | Iter:   60 | Time: 00:00:14 | Train Loss: 2.0381 | Average Loss: 2.2430
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:16 | Iter:    0 | Time: 00:00:15 | Train Loss: 2.0454 | Average Loss: 2.2403
# Epoch:16 | Iter:   20 | Time: 00:00:15 | Train Loss: 2.0182 | Average Loss: 2.2367
# Epoch:16 | Iter:   40 | Time: 00:00:15 | Train Loss: 2.0263 | Average Loss: 2.2333
# Epoch:16 | Iter:   60 | Time: 00:00:15 | Train Loss: 2.0202 | Average Loss: 2.2298
# Accuracy: 0.708333 | Time: 00:00:00
# Epoch:17 | Iter:    0 | Time: 00:00:16 | Train Loss: 2.0390 | Average Loss: 2.2273
# Epoch:17 | Iter:   20 | Time: 00:00:16 | Train Loss: 2.0109 | Average Loss: 2.2241
# Epoch:17 | Iter:   40 | Time: 00:00:16 | Train Loss: 2.0089 | Average Loss: 2.2209
# Epoch:17 | Iter:   60 | Time: 00:00:16 | Train Loss: 2.0067 | Average Loss: 2.2176
# Accuracy: 0.716146 | Time: 00:00:00
# Epoch:18 | Iter:    0 | Time: 00:00:17 | Train Loss: 2.0126 | Average Loss: 2.2152
# Epoch:18 | Iter:   20 | Time: 00:00:17 | Train Loss: 2.0029 | Average Loss: 2.2122
# Epoch:18 | Iter:   40 | Time: 00:00:17 | Train Loss: 1.9973 | Average Loss: 2.2091
# Epoch:18 | Iter:   60 | Time: 00:00:18 | Train Loss: 2.0050 | Average Loss: 2.2060
# Accuracy: 0.690104 | Time: 00:00:00
# Epoch:19 | Iter:    0 | Time: 00:00:18 | Train Loss: 2.0043 | Average Loss: 2.2038
# Epoch:19 | Iter:   20 | Time: 00:00:18 | Train Loss: 1.9810 | Average Loss: 2.2008
# Epoch:19 | Iter:   40 | Time: 00:00:18 | Train Loss: 1.9829 | Average Loss: 2.1979
# Epoch:19 | Iter:   60 | Time: 00:00:19 | Train Loss: 1.9842 | Average Loss: 2.1951
# Accuracy: 0.700521 | Time: 00:00:00
# Epoch:20 | Iter:    0 | Time: 00:00:19 | Train Loss: 2.0012 | Average Loss: 2.1930
# Epoch:20 | Iter:   20 | Time: 00:00:19 | Train Loss: 1.9780 | Average Loss: 2.1902
# Epoch:20 | Iter:   40 | Time: 00:00:19 | Train Loss: 1.9826 | Average Loss: 2.1875
# Epoch:20 | Iter:   60 | Time: 00:00:20 | Train Loss: 1.9884 | Average Loss: 2.1848
# Accuracy: 0.695312 | Time: 00:00:00
# Epoch:21 | Iter:    0 | Time: 00:00:20 | Train Loss: 1.9928 | Average Loss: 2.1828
# Epoch:21 | Iter:   20 | Time: 00:00:20 | Train Loss: 1.9694 | Average Loss: 2.1802
# Epoch:21 | Iter:   40 | Time: 00:00:20 | Train Loss: 1.9714 | Average Loss: 2.1776
# Epoch:21 | Iter:   60 | Time: 00:00:21 | Train Loss: 1.9897 | Average Loss: 2.1751
# Accuracy: 0.682292 | Time: 00:00:00
# Epoch:22 | Iter:    0 | Time: 00:00:21 | Train Loss: 1.9827 | Average Loss: 2.1732
# Epoch:22 | Iter:   20 | Time: 00:00:21 | Train Loss: 1.9599 | Average Loss: 2.1708
# Epoch:22 | Iter:   40 | Time: 00:00:21 | Train Loss: 1.9654 | Average Loss: 2.1684
# Epoch:22 | Iter:   60 | Time: 00:00:22 | Train Loss: 1.9691 | Average Loss: 2.1660
# Accuracy: 0.703125 | Time: 00:00:00
# Epoch:23 | Iter:    0 | Time: 00:00:22 | Train Loss: 1.9824 | Average Loss: 2.1642
# Epoch:23 | Iter:   20 | Time: 00:00:22 | Train Loss: 1.9466 | Average Loss: 2.1619
# Epoch:23 | Iter:   40 | Time: 00:00:22 | Train Loss: 1.9615 | Average Loss: 2.1596
# Epoch:23 | Iter:   60 | Time: 00:00:23 | Train Loss: 1.9658 | Average Loss: 2.1573
# Accuracy: 0.697917 | Time: 00:00:00
# Epoch:24 | Iter:    0 | Time: 00:00:23 | Train Loss: 1.9562 | Average Loss: 2.1557
# Epoch:24 | Iter:   20 | Time: 00:00:23 | Train Loss: 1.9553 | Average Loss: 2.1535
# Epoch:24 | Iter:   40 | Time: 00:00:23 | Train Loss: 1.9711 | Average Loss: 2.1513
# Epoch:24 | Iter:   60 | Time: 00:00:24 | Train Loss: 1.9693 | Average Loss: 2.1492
# Accuracy: 0.692708 | Time: 00:00:00
# Epoch:25 | Iter:    0 | Time: 00:00:24 | Train Loss: 1.9634 | Average Loss: 2.1476
# Epoch:25 | Iter:   20 | Time: 00:00:24 | Train Loss: 1.9484 | Average Loss: 2.1456
# Epoch:25 | Iter:   40 | Time: 00:00:24 | Train Loss: 1.9468 | Average Loss: 2.1436
# Epoch:25 | Iter:   60 | Time: 00:00:25 | Train Loss: 1.9640 | Average Loss: 2.1416
# Accuracy: 0.716146 | Time: 00:00:00
# Epoch:26 | Iter:    0 | Time: 00:00:25 | Train Loss: 1.9775 | Average Loss: 2.1401
# Epoch:26 | Iter:   20 | Time: 00:00:25 | Train Loss: 1.9358 | Average Loss: 2.1382
# Epoch:26 | Iter:   40 | Time: 00:00:25 | Train Loss: 1.9389 | Average Loss: 2.1362
# Epoch:26 | Iter:   60 | Time: 00:00:26 | Train Loss: 1.9475 | Average Loss: 2.1343
# Accuracy: 0.708333 | Time: 00:00:00
# Epoch:27 | Iter:    0 | Time: 00:00:26 | Train Loss: 1.9518 | Average Loss: 2.1329
# Epoch:27 | Iter:   20 | Time: 00:00:26 | Train Loss: 1.9295 | Average Loss: 2.1310
# Epoch:27 | Iter:   40 | Time: 00:00:26 | Train Loss: 1.9413 | Average Loss: 2.1292
# Epoch:27 | Iter:   60 | Time: 00:00:27 | Train Loss: 1.9502 | Average Loss: 2.1273
# Accuracy: 0.695312 | Time: 00:00:00
# Epoch:28 | Iter:    0 | Time: 00:00:27 | Train Loss: 1.9481 | Average Loss: 2.1260
# Epoch:28 | Iter:   20 | Time: 00:00:27 | Train Loss: 1.9322 | Average Loss: 2.1243
# Epoch:28 | Iter:   40 | Time: 00:00:27 | Train Loss: 1.9398 | Average Loss: 2.1225
# Epoch:28 | Iter:   60 | Time: 00:00:28 | Train Loss: 1.9391 | Average Loss: 2.1208
# Accuracy: 0.679688 | Time: 00:00:00
# Epoch:29 | Iter:    0 | Time: 00:00:28 | Train Loss: 1.9483 | Average Loss: 2.1195
# Epoch:29 | Iter:   20 | Time: 00:00:28 | Train Loss: 1.9229 | Average Loss: 2.1178
# Epoch:29 | Iter:   40 | Time: 00:00:28 | Train Loss: 1.9299 | Average Loss: 2.1162
# Epoch:29 | Iter:   60 | Time: 00:00:29 | Train Loss: 1.9337 | Average Loss: 2.1145
# Accuracy: 0.703125 | Time: 00:00:00
# Epoch:30 | Iter:    0 | Time: 00:00:29 | Train Loss: 1.9472 | Average Loss: 2.1133
# Epoch:30 | Iter:   20 | Time: 00:00:29 | Train Loss: 1.9220 | Average Loss: 2.1117
# Epoch:30 | Iter:   40 | Time: 00:00:29 | Train Loss: 1.9329 | Average Loss: 2.1101
# Epoch:30 | Iter:   60 | Time: 00:00:30 | Train Loss: 1.9348 | Average Loss: 2.1086
# Accuracy: 0.671875 | Time: 00:00:00
# Epoch:31 | Iter:    0 | Time: 00:00:30 | Train Loss: 1.9357 | Average Loss: 2.1074
# Epoch:31 | Iter:   20 | Time: 00:00:30 | Train Loss: 1.9206 | Average Loss: 2.1059
# Epoch:31 | Iter:   40 | Time: 00:00:30 | Train Loss: 1.9228 | Average Loss: 2.1044
# Epoch:31 | Iter:   60 | Time: 00:00:31 | Train Loss: 1.9318 | Average Loss: 2.1028
# Accuracy: 0.679688 | Time: 00:00:00
# Epoch:32 | Iter:    0 | Time: 00:00:31 | Train Loss: 1.9314 | Average Loss: 2.1017
# Epoch:32 | Iter:   20 | Time: 00:00:31 | Train Loss: 1.9182 | Average Loss: 2.1003
# Epoch:32 | Iter:   40 | Time: 00:00:32 | Train Loss: 1.9186 | Average Loss: 2.0988
# Epoch:32 | Iter:   60 | Time: 00:00:32 | Train Loss: 1.9227 | Average Loss: 2.0974
# Accuracy: 0.708333 | Time: 00:00:00
# Epoch:33 | Iter:    0 | Time: 00:00:32 | Train Loss: 1.9292 | Average Loss: 2.0963
# Epoch:33 | Iter:   20 | Time: 00:00:32 | Train Loss: 1.9117 | Average Loss: 2.0949
# Epoch:33 | Iter:   40 | Time: 00:00:33 | Train Loss: 1.9210 | Average Loss: 2.0935
# Epoch:33 | Iter:   60 | Time: 00:00:33 | Train Loss: 1.9252 | Average Loss: 2.0921
# Accuracy: 0.692708 | Time: 00:00:00
# Epoch:34 | Iter:    0 | Time: 00:00:33 | Train Loss: 1.9246 | Average Loss: 2.0911
# Epoch:34 | Iter:   20 | Time: 00:00:33 | Train Loss: 1.9120 | Average Loss: 2.0897
# Epoch:34 | Iter:   40 | Time: 00:00:34 | Train Loss: 1.9118 | Average Loss: 2.0884
# Epoch:34 | Iter:   60 | Time: 00:00:34 | Train Loss: 1.9227 | Average Loss: 2.0870
# Accuracy: 0.708333 | Time: 00:00:00
# Epoch:35 | Iter:    0 | Time: 00:00:34 | Train Loss: 1.9241 | Average Loss: 2.0861
# Epoch:35 | Iter:   20 | Time: 00:00:35 | Train Loss: 1.9042 | Average Loss: 2.0848
# Epoch:35 | Iter:   40 | Time: 00:00:35 | Train Loss: 1.9118 | Average Loss: 2.0835
# Epoch:35 | Iter:   60 | Time: 00:00:35 | Train Loss: 1.9166 | Average Loss: 2.0822
# Accuracy: 0.710938 | Time: 00:00:00
# Epoch:36 | Iter:    0 | Time: 00:00:36 | Train Loss: 1.9196 | Average Loss: 2.0813
# Epoch:36 | Iter:   20 | Time: 00:00:36 | Train Loss: 1.9051 | Average Loss: 2.0800
# Epoch:36 | Iter:   40 | Time: 00:00:36 | Train Loss: 1.9156 | Average Loss: 2.0788
# Epoch:36 | Iter:   60 | Time: 00:00:36 | Train Loss: 1.9170 | Average Loss: 2.0776
# Accuracy: 0.708333 | Time: 00:00:00
# Epoch:37 | Iter:    0 | Time: 00:00:37 | Train Loss: 1.9228 | Average Loss: 2.0767
# Epoch:37 | Iter:   20 | Time: 00:00:37 | Train Loss: 1.9104 | Average Loss: 2.0755
# Epoch:37 | Iter:   40 | Time: 00:00:37 | Train Loss: 1.9102 | Average Loss: 2.0744
# Epoch:37 | Iter:   60 | Time: 00:00:37 | Train Loss: 1.9100 | Average Loss: 2.0732
# Accuracy: 0.692708 | Time: 00:00:00
# Epoch:38 | Iter:    0 | Time: 00:00:38 | Train Loss: 1.9229 | Average Loss: 2.0724
# Epoch:38 | Iter:   20 | Time: 00:00:38 | Train Loss: 1.9057 | Average Loss: 2.0712
# Epoch:38 | Iter:   40 | Time: 00:00:38 | Train Loss: 1.9105 | Average Loss: 2.0701
# Epoch:38 | Iter:   60 | Time: 00:00:38 | Train Loss: 1.9107 | Average Loss: 2.0690
# Accuracy: 0.692708 | Time: 00:00:00
# Epoch:39 | Iter:    0 | Time: 00:00:39 | Train Loss: 1.9183 | Average Loss: 2.0682
# Epoch:39 | Iter:   20 | Time: 00:00:39 | Train Loss: 1.9039 | Average Loss: 2.0671
# Epoch:39 | Iter:   40 | Time: 00:00:39 | Train Loss: 1.9066 | Average Loss: 2.0660
# Epoch:39 | Iter:   60 | Time: 00:00:39 | Train Loss: 1.9049 | Average Loss: 2.0649
# Accuracy: 0.705729 | Time: 00:00:00
# Epoch:40 | Iter:    0 | Time: 00:00:40 | Train Loss: 1.9117 | Average Loss: 2.0641
# Epoch:40 | Iter:   20 | Time: 00:00:40 | Train Loss: 1.9005 | Average Loss: 2.0631
# Epoch:40 | Iter:   40 | Time: 00:00:40 | Train Loss: 1.9033 | Average Loss: 2.0620
# Epoch:40 | Iter:   60 | Time: 00:00:40 | Train Loss: 1.9064 | Average Loss: 2.0610
# Accuracy: 0.692708 | Time: 00:00:00
# Epoch:41 | Iter:    0 | Time: 00:00:41 | Train Loss: 1.9173 | Average Loss: 2.0602
# Epoch:41 | Iter:   20 | Time: 00:00:41 | Train Loss: 1.8996 | Average Loss: 2.0592
# Epoch:41 | Iter:   40 | Time: 00:00:41 | Train Loss: 1.9036 | Average Loss: 2.0582
# Epoch:41 | Iter:   60 | Time: 00:00:41 | Train Loss: 1.9048 | Average Loss: 2.0572
# Accuracy: 0.692708 | Time: 00:00:00
# Epoch:42 | Iter:    0 | Time: 00:00:42 | Train Loss: 1.9117 | Average Loss: 2.0565
# Epoch:42 | Iter:   20 | Time: 00:00:42 | Train Loss: 1.9001 | Average Loss: 2.0555
# Epoch:42 | Iter:   40 | Time: 00:00:42 | Train Loss: 1.8967 | Average Loss: 2.0546
# Epoch:42 | Iter:   60 | Time: 00:00:42 | Train Loss: 1.9128 | Average Loss: 2.0536
# Accuracy: 0.721354 | Time: 00:00:00
# Epoch:43 | Iter:    0 | Time: 00:00:43 | Train Loss: 1.9129 | Average Loss: 2.0529
# Epoch:43 | Iter:   20 | Time: 00:00:43 | Train Loss: 1.8975 | Average Loss: 2.0520
# Epoch:43 | Iter:   40 | Time: 00:00:43 | Train Loss: 1.8979 | Average Loss: 2.0511
# Epoch:43 | Iter:   60 | Time: 00:00:43 | Train Loss: 1.9019 | Average Loss: 2.0502
# Accuracy: 0.692708 | Time: 00:00:00
# Epoch:44 | Iter:    0 | Time: 00:00:44 | Train Loss: 1.9091 | Average Loss: 2.0495
# Epoch:44 | Iter:   20 | Time: 00:00:44 | Train Loss: 1.9004 | Average Loss: 2.0486
# Epoch:44 | Iter:   40 | Time: 00:00:44 | Train Loss: 1.8999 | Average Loss: 2.0477
# Epoch:44 | Iter:   60 | Time: 00:00:44 | Train Loss: 1.9043 | Average Loss: 2.0468
# Accuracy: 0.695312 | Time: 00:00:00
# Epoch:45 | Iter:    0 | Time: 00:00:45 | Train Loss: 1.9054 | Average Loss: 2.0462
# Epoch:45 | Iter:   20 | Time: 00:00:45 | Train Loss: 1.8924 | Average Loss: 2.0453
# Epoch:45 | Iter:   40 | Time: 00:00:45 | Train Loss: 1.8944 | Average Loss: 2.0444
# Epoch:45 | Iter:   60 | Time: 00:00:45 | Train Loss: 1.9010 | Average Loss: 2.0436
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:46 | Iter:    0 | Time: 00:00:46 | Train Loss: 1.9068 | Average Loss: 2.0429
# Epoch:46 | Iter:   20 | Time: 00:00:46 | Train Loss: 1.8926 | Average Loss: 2.0421
# Epoch:46 | Iter:   40 | Time: 00:00:46 | Train Loss: 1.8941 | Average Loss: 2.0413
# Epoch:46 | Iter:   60 | Time: 00:00:47 | Train Loss: 1.9044 | Average Loss: 2.0405
# Accuracy: 0.716146 | Time: 00:00:00
# Epoch:47 | Iter:    0 | Time: 00:00:47 | Train Loss: 1.9044 | Average Loss: 2.0399
# Epoch:47 | Iter:   20 | Time: 00:00:47 | Train Loss: 1.8943 | Average Loss: 2.0391
# Epoch:47 | Iter:   40 | Time: 00:00:47 | Train Loss: 1.8947 | Average Loss: 2.0383
# Epoch:47 | Iter:   60 | Time: 00:00:48 | Train Loss: 1.9013 | Average Loss: 2.0375
# Accuracy: 0.674479 | Time: 00:00:00
# Epoch:48 | Iter:    0 | Time: 00:00:48 | Train Loss: 1.9032 | Average Loss: 2.0369
# Epoch:48 | Iter:   20 | Time: 00:00:48 | Train Loss: 1.8918 | Average Loss: 2.0361
# Epoch:48 | Iter:   40 | Time: 00:00:48 | Train Loss: 1.8941 | Average Loss: 2.0354
# Epoch:48 | Iter:   60 | Time: 00:00:49 | Train Loss: 1.8989 | Average Loss: 2.0346
# Accuracy: 0.729167 | Time: 00:00:00
# Epoch:49 | Iter:    0 | Time: 00:00:49 | Train Loss: 1.9005 | Average Loss: 2.0340
# Epoch:49 | Iter:   20 | Time: 00:00:49 | Train Loss: 1.8901 | Average Loss: 2.0333
# Epoch:49 | Iter:   40 | Time: 00:00:49 | Train Loss: 1.8926 | Average Loss: 2.0325
# Epoch:49 | Iter:   60 | Time: 00:00:50 | Train Loss: 1.8962 | Average Loss: 2.0318
# Accuracy: 0.710938 | Time: 00:00:00
# Epoch:50 | Iter:    0 | Time: 00:00:50 | Train Loss: 1.8982 | Average Loss: 2.0312
# Epoch:50 | Iter:   20 | Time: 00:00:50 | Train Loss: 1.8893 | Average Loss: 2.0305
# Epoch:50 | Iter:   40 | Time: 00:00:50 | Train Loss: 1.8914 | Average Loss: 2.0298
# Epoch:50 | Iter:   60 | Time: 00:00:51 | Train Loss: 1.8978 | Average Loss: 2.0291
# Accuracy: 0.718750 | Time: 00:00:00
# Epoch:51 | Iter:    0 | Time: 00:00:51 | Train Loss: 1.8994 | Average Loss: 2.0285
# Epoch:51 | Iter:   20 | Time: 00:00:51 | Train Loss: 1.8890 | Average Loss: 2.0278
# Epoch:51 | Iter:   40 | Time: 00:00:51 | Train Loss: 1.8918 | Average Loss: 2.0271
# Epoch:51 | Iter:   60 | Time: 00:00:52 | Train Loss: 1.8924 | Average Loss: 2.0264
# Accuracy: 0.723958 | Time: 00:00:00
# Epoch:52 | Iter:    0 | Time: 00:00:52 | Train Loss: 1.8999 | Average Loss: 2.0259
# Epoch:52 | Iter:   20 | Time: 00:00:52 | Train Loss: 1.8890 | Average Loss: 2.0252
# Epoch:52 | Iter:   40 | Time: 00:00:52 | Train Loss: 1.8907 | Average Loss: 2.0246
# Epoch:52 | Iter:   60 | Time: 00:00:53 | Train Loss: 1.8915 | Average Loss: 2.0239
# Accuracy: 0.705729 | Time: 00:00:00
# Epoch:53 | Iter:    0 | Time: 00:00:53 | Train Loss: 1.8996 | Average Loss: 2.0234
# Epoch:53 | Iter:   20 | Time: 00:00:53 | Train Loss: 1.8865 | Average Loss: 2.0228
# Epoch:53 | Iter:   40 | Time: 00:00:53 | Train Loss: 1.8905 | Average Loss: 2.0221
# Epoch:53 | Iter:   60 | Time: 00:00:54 | Train Loss: 1.8918 | Average Loss: 2.0215
# Accuracy: 0.710938 | Time: 00:00:00
# Epoch:54 | Iter:    0 | Time: 00:00:54 | Train Loss: 1.8982 | Average Loss: 2.0210
# Epoch:54 | Iter:   20 | Time: 00:00:54 | Train Loss: 1.8871 | Average Loss: 2.0203
# Epoch:54 | Iter:   40 | Time: 00:00:54 | Train Loss: 1.8909 | Average Loss: 2.0197
# Epoch:54 | Iter:   60 | Time: 00:00:55 | Train Loss: 1.8931 | Average Loss: 2.0191
# Accuracy: 0.729167 | Time: 00:00:00
# Epoch:55 | Iter:    0 | Time: 00:00:55 | Train Loss: 1.8954 | Average Loss: 2.0186
# Epoch:55 | Iter:   20 | Time: 00:00:55 | Train Loss: 1.8876 | Average Loss: 2.0180
# Epoch:55 | Iter:   40 | Time: 00:00:55 | Train Loss: 1.8914 | Average Loss: 2.0174
# Epoch:55 | Iter:   60 | Time: 00:00:56 | Train Loss: 1.8900 | Average Loss: 2.0168
# Accuracy: 0.710938 | Time: 00:00:00
# Epoch:56 | Iter:    0 | Time: 00:00:56 | Train Loss: 1.8968 | Average Loss: 2.0163
# Epoch:56 | Iter:   20 | Time: 00:00:56 | Train Loss: 1.8876 | Average Loss: 2.0157
# Epoch:56 | Iter:   40 | Time: 00:00:56 | Train Loss: 1.8899 | Average Loss: 2.0152
# Epoch:56 | Iter:   60 | Time: 00:00:57 | Train Loss: 1.8885 | Average Loss: 2.0146
# Accuracy: 0.703125 | Time: 00:00:00
# Epoch:57 | Iter:    0 | Time: 00:00:57 | Train Loss: 1.8926 | Average Loss: 2.0141
# Epoch:57 | Iter:   20 | Time: 00:00:57 | Train Loss: 1.8870 | Average Loss: 2.0135
# Epoch:57 | Iter:   40 | Time: 00:00:57 | Train Loss: 1.8874 | Average Loss: 2.0130
# Epoch:57 | Iter:   60 | Time: 00:00:58 | Train Loss: 1.8890 | Average Loss: 2.0124
# Accuracy: 0.713542 | Time: 00:00:00
# Epoch:58 | Iter:    0 | Time: 00:00:58 | Train Loss: 1.8932 | Average Loss: 2.0120
# Epoch:58 | Iter:   20 | Time: 00:00:58 | Train Loss: 1.8861 | Average Loss: 2.0114
# Epoch:58 | Iter:   40 | Time: 00:00:58 | Train Loss: 1.8868 | Average Loss: 2.0109
# Epoch:58 | Iter:   60 | Time: 00:00:59 | Train Loss: 1.8946 | Average Loss: 2.0103
# Accuracy: 0.718750 | Time: 00:00:00
# Epoch:59 | Iter:    0 | Time: 00:00:59 | Train Loss: 1.8945 | Average Loss: 2.0099
# Epoch:59 | Iter:   20 | Time: 00:00:59 | Train Loss: 1.8857 | Average Loss: 2.0094
# Epoch:59 | Iter:   40 | Time: 00:00:59 | Train Loss: 1.8882 | Average Loss: 2.0088
# Epoch:59 | Iter:   60 | Time: 00:01:00 | Train Loss: 1.8935 | Average Loss: 2.0083
# Accuracy: 0.695312 | Time: 00:00:00
# Epoch:60 | Iter:    0 | Time: 00:01:00 | Train Loss: 1.8952 | Average Loss: 2.0079
# Epoch:60 | Iter:   20 | Time: 00:01:00 | Train Loss: 1.8864 | Average Loss: 2.0074
# Epoch:60 | Iter:   40 | Time: 00:01:00 | Train Loss: 1.8855 | Average Loss: 2.0068
# Epoch:60 | Iter:   60 | Time: 00:01:01 | Train Loss: 1.8896 | Average Loss: 2.0063
# Accuracy: 0.697917 | Time: 00:00:00

# %% [markdown]
# **Answer**:
#
# Technique 2: Different activation function (Sigmoid, Leaky ReLU, tanh)
#
# Data augmentation: No augmentation done
#
# Data normalization: First we calculated the mean and then subtracted from the image, which resulted in zero-centered image
#
# Layer 1: Convolution layer with 64 output channels, followed by batchnormalization, tanh activation and MaxPooling layer
#
# Layer 2: Convolution layer with 128 output channels, followed by Sigmoid activation and MaxPooling layer
#
# Layer 3: NN layer with 4608 input node and 1024 output nodes. Batchnormalization and LeakyReLU is also added.
#
# Layer 4: NN layer with 1024 input and 16 output nodes. This is followed by batchnormalization and sigmoid activation. Dropout with p=0.5 was also added before this
#
#
# Accuracy on test set: **0.729167**
#
# Accuracy increases/decreases: Increase

# %% [markdown]
# ### Technique 3

# %%
#--------------------------------------------------
#    Load Training Data and Testing Data
#--------------------------------------------------
# load data into size (64, 64)
img_size = (64, 64)

batch_size = 64         # training sample number per batch

# load training dataset

trainloader_small = list(load_dataset('./data/train/', img_size, batch_size=batch_size, shuffle=True, augment=True, zero_centered=True))
train_num = len(trainloader_small)

print("Finish loading %d minibatches (batch_size=%d) of training samples." % (train_num, batch_size))

# load testing dataset

testloader_small = list(load_dataset('./data/test/', img_size, num_per_class=50, batch_size=batch_size, zero_centered=True))

test_num = len(testloader_small)

print("Finish loading %d minibatches (batch_size=%d) of testing samples." % (test_num, batch_size))
# Out:
# Loading images from class: 0
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:43: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 75 minibatches (batch_size=64) of training samples.
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 6 minibatches (batch_size=64) of testing samples.

# %%
#--------------------------------------------------
#       Define Network Architecture
#--------------------------------------------------
class HorNet(nn.Module):
    def __init__(self):
      super(HorNet,self).__init__()  
           
      self.layer1 = torch.nn.Sequential(
        nn.Conv2d(1, 64, 3),
        nn.BatchNorm2d(64),
        nn.Tanh(),
        nn.MaxPool2d(4, stride=4)
      )
      self.layer2 = torch.nn.Sequential(
        nn.Conv2d(64, 128, 3),
        nn.BatchNorm2d(128),
        nn.Sigmoid(),
        nn.MaxPool2d(2, stride=2)
      )
      
      self.classifier1 = nn.Sequential(
         nn.Linear(4608, 1024), 
         nn.BatchNorm1d(1024),
         nn.LeakyReLU()
      )
      self.classifier2 = nn.Sequential(
         nn.Linear(1024, 16),
         nn.BatchNorm1d(16),
         nn.Sigmoid()
      )

      self.dropout = nn.Dropout(0.5)
      
    def forward(self, x):
      x = self.layer1(x)
      x = self.layer2(x)  
      x = torch.flatten(x, 1)
      x = self.dropout(x)
      x = self.classifier1(x)
      x = self.classifier2(x)
      return x

# %%
#--------------------------------------------------
#       Start Training & Evaluation
#--------------------------------------------------
net = HorNet() 
train_option = {}
train_option['lr'] = 0.002
train_option['epoch'] = 60
train_option['device'] = 'gpu'
trainModel(net, trainloader_small, train_option, testloader_small)
# Out:
# Epoch: 1 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.7984 | Average Loss: 2.7984
# Epoch: 1 | Iter:   20 | Time: 00:00:00 | Train Loss: 2.5673 | Average Loss: 2.6438
# Epoch: 1 | Iter:   40 | Time: 00:00:00 | Train Loss: 2.5484 | Average Loss: 2.6119
# Epoch: 1 | Iter:   60 | Time: 00:00:00 | Train Loss: 2.5119 | Average Loss: 2.5904
# Accuracy: 0.419271 | Time: 00:00:00
# Epoch: 2 | Iter:    0 | Time: 00:00:01 | Train Loss: 2.4945 | Average Loss: 2.5755
# Epoch: 2 | Iter:   20 | Time: 00:00:01 | Train Loss: 2.4561 | Average Loss: 2.5582
# Epoch: 2 | Iter:   40 | Time: 00:00:01 | Train Loss: 2.4330 | Average Loss: 2.5437
# Epoch: 2 | Iter:   60 | Time: 00:00:01 | Train Loss: 2.4514 | Average Loss: 2.5312
# Accuracy: 0.494792 | Time: 00:00:00
# Epoch: 3 | Iter:    0 | Time: 00:00:02 | Train Loss: 2.4043 | Average Loss: 2.5212
# Epoch: 3 | Iter:   20 | Time: 00:00:02 | Train Loss: 2.4014 | Average Loss: 2.5096
# Epoch: 3 | Iter:   40 | Time: 00:00:02 | Train Loss: 2.3859 | Average Loss: 2.4981
# Epoch: 3 | Iter:   60 | Time: 00:00:02 | Train Loss: 2.3926 | Average Loss: 2.4877
# Accuracy: 0.588542 | Time: 00:00:00
# Epoch: 4 | Iter:    0 | Time: 00:00:03 | Train Loss: 2.3484 | Average Loss: 2.4805
# Epoch: 4 | Iter:   20 | Time: 00:00:03 | Train Loss: 2.3541 | Average Loss: 2.4714
# Epoch: 4 | Iter:   40 | Time: 00:00:03 | Train Loss: 2.3228 | Average Loss: 2.4623
# Epoch: 4 | Iter:   60 | Time: 00:00:03 | Train Loss: 2.3400 | Average Loss: 2.4543
# Accuracy: 0.596354 | Time: 00:00:00
# Epoch: 5 | Iter:    0 | Time: 00:00:04 | Train Loss: 2.3012 | Average Loss: 2.4486
# Epoch: 5 | Iter:   20 | Time: 00:00:04 | Train Loss: 2.3225 | Average Loss: 2.4413
# Epoch: 5 | Iter:   40 | Time: 00:00:04 | Train Loss: 2.2949 | Average Loss: 2.4340
# Epoch: 5 | Iter:   60 | Time: 00:00:05 | Train Loss: 2.3143 | Average Loss: 2.4274
# Accuracy: 0.630208 | Time: 00:00:00
# Epoch: 6 | Iter:    0 | Time: 00:00:05 | Train Loss: 2.2819 | Average Loss: 2.4225
# Epoch: 6 | Iter:   20 | Time: 00:00:05 | Train Loss: 2.2881 | Average Loss: 2.4162
# Epoch: 6 | Iter:   40 | Time: 00:00:05 | Train Loss: 2.2661 | Average Loss: 2.4102
# Epoch: 6 | Iter:   60 | Time: 00:00:06 | Train Loss: 2.2809 | Average Loss: 2.4046
# Accuracy: 0.575521 | Time: 00:00:00
# Epoch: 7 | Iter:    0 | Time: 00:00:06 | Train Loss: 2.2519 | Average Loss: 2.4004
# Epoch: 7 | Iter:   20 | Time: 00:00:06 | Train Loss: 2.2484 | Average Loss: 2.3950
# Epoch: 7 | Iter:   40 | Time: 00:00:06 | Train Loss: 2.2434 | Average Loss: 2.3895
# Epoch: 7 | Iter:   60 | Time: 00:00:07 | Train Loss: 2.2649 | Average Loss: 2.3844
# Accuracy: 0.651042 | Time: 00:00:00
# Epoch: 8 | Iter:    0 | Time: 00:00:07 | Train Loss: 2.2287 | Average Loss: 2.3805
# Epoch: 8 | Iter:   20 | Time: 00:00:07 | Train Loss: 2.2273 | Average Loss: 2.3756
# Epoch: 8 | Iter:   40 | Time: 00:00:07 | Train Loss: 2.2100 | Average Loss: 2.3705
# Epoch: 8 | Iter:   60 | Time: 00:00:08 | Train Loss: 2.2322 | Average Loss: 2.3657
# Accuracy: 0.630208 | Time: 00:00:00
# Epoch: 9 | Iter:    0 | Time: 00:00:08 | Train Loss: 2.2083 | Average Loss: 2.3622
# Epoch: 9 | Iter:   20 | Time: 00:00:08 | Train Loss: 2.2104 | Average Loss: 2.3577
# Epoch: 9 | Iter:   40 | Time: 00:00:08 | Train Loss: 2.1944 | Average Loss: 2.3531
# Epoch: 9 | Iter:   60 | Time: 00:00:09 | Train Loss: 2.2186 | Average Loss: 2.3488
# Accuracy: 0.661458 | Time: 00:00:00
# Epoch:10 | Iter:    0 | Time: 00:00:09 | Train Loss: 2.1860 | Average Loss: 2.3456
# Epoch:10 | Iter:   20 | Time: 00:00:09 | Train Loss: 2.1854 | Average Loss: 2.3415
# Epoch:10 | Iter:   40 | Time: 00:00:09 | Train Loss: 2.1673 | Average Loss: 2.3372
# Epoch:10 | Iter:   60 | Time: 00:00:10 | Train Loss: 2.1759 | Average Loss: 2.3331
# Accuracy: 0.666667 | Time: 00:00:00
# Epoch:11 | Iter:    0 | Time: 00:00:10 | Train Loss: 2.1664 | Average Loss: 2.3301
# Epoch:11 | Iter:   20 | Time: 00:00:10 | Train Loss: 2.1753 | Average Loss: 2.3262
# Epoch:11 | Iter:   40 | Time: 00:00:10 | Train Loss: 2.1556 | Average Loss: 2.3221
# Epoch:11 | Iter:   60 | Time: 00:00:11 | Train Loss: 2.1791 | Average Loss: 2.3183
# Accuracy: 0.674479 | Time: 00:00:00
# Epoch:12 | Iter:    0 | Time: 00:00:11 | Train Loss: 2.1637 | Average Loss: 2.3156
# Epoch:12 | Iter:   20 | Time: 00:00:11 | Train Loss: 2.1669 | Average Loss: 2.3120
# Epoch:12 | Iter:   40 | Time: 00:00:11 | Train Loss: 2.1305 | Average Loss: 2.3083
# Epoch:12 | Iter:   60 | Time: 00:00:12 | Train Loss: 2.1625 | Average Loss: 2.3048
# Accuracy: 0.679688 | Time: 00:00:00
# Epoch:13 | Iter:    0 | Time: 00:00:12 | Train Loss: 2.1238 | Average Loss: 2.3021
# Epoch:13 | Iter:   20 | Time: 00:00:12 | Train Loss: 2.1613 | Average Loss: 2.2987
# Epoch:13 | Iter:   40 | Time: 00:00:12 | Train Loss: 2.1200 | Average Loss: 2.2952
# Epoch:13 | Iter:   60 | Time: 00:00:13 | Train Loss: 2.1492 | Average Loss: 2.2919
# Accuracy: 0.666667 | Time: 00:00:00
# Epoch:14 | Iter:    0 | Time: 00:00:13 | Train Loss: 2.1137 | Average Loss: 2.2894
# Epoch:14 | Iter:   20 | Time: 00:00:13 | Train Loss: 2.1263 | Average Loss: 2.2862
# Epoch:14 | Iter:   40 | Time: 00:00:14 | Train Loss: 2.1136 | Average Loss: 2.2829
# Epoch:14 | Iter:   60 | Time: 00:00:14 | Train Loss: 2.1167 | Average Loss: 2.2798
# Accuracy: 0.669271 | Time: 00:00:00
# Epoch:15 | Iter:    0 | Time: 00:00:14 | Train Loss: 2.1101 | Average Loss: 2.2774
# Epoch:15 | Iter:   20 | Time: 00:00:14 | Train Loss: 2.0990 | Average Loss: 2.2744
# Epoch:15 | Iter:   40 | Time: 00:00:15 | Train Loss: 2.0886 | Average Loss: 2.2713
# Epoch:15 | Iter:   60 | Time: 00:00:15 | Train Loss: 2.1210 | Average Loss: 2.2683
# Accuracy: 0.692708 | Time: 00:00:00
# Epoch:16 | Iter:    0 | Time: 00:00:15 | Train Loss: 2.0900 | Average Loss: 2.2661
# Epoch:16 | Iter:   20 | Time: 00:00:15 | Train Loss: 2.0969 | Average Loss: 2.2632
# Epoch:16 | Iter:   40 | Time: 00:00:16 | Train Loss: 2.0759 | Average Loss: 2.2603
# Epoch:16 | Iter:   60 | Time: 00:00:16 | Train Loss: 2.0922 | Average Loss: 2.2575
# Accuracy: 0.653646 | Time: 00:00:00
# Epoch:17 | Iter:    0 | Time: 00:00:16 | Train Loss: 2.0771 | Average Loss: 2.2553
# Epoch:17 | Iter:   20 | Time: 00:00:16 | Train Loss: 2.0732 | Average Loss: 2.2526
# Epoch:17 | Iter:   40 | Time: 00:00:17 | Train Loss: 2.0549 | Average Loss: 2.2497
# Epoch:17 | Iter:   60 | Time: 00:00:17 | Train Loss: 2.0754 | Average Loss: 2.2471
# Accuracy: 0.635417 | Time: 00:00:00
# Epoch:18 | Iter:    0 | Time: 00:00:17 | Train Loss: 2.0695 | Average Loss: 2.2452
# Epoch:18 | Iter:   20 | Time: 00:00:17 | Train Loss: 2.0889 | Average Loss: 2.2427
# Epoch:18 | Iter:   40 | Time: 00:00:18 | Train Loss: 2.0553 | Average Loss: 2.2401
# Epoch:18 | Iter:   60 | Time: 00:00:18 | Train Loss: 2.0821 | Average Loss: 2.2376
# Accuracy: 0.648438 | Time: 00:00:00
# Epoch:19 | Iter:    0 | Time: 00:00:18 | Train Loss: 2.0650 | Average Loss: 2.2357
# Epoch:19 | Iter:   20 | Time: 00:00:18 | Train Loss: 2.0542 | Average Loss: 2.2333
# Epoch:19 | Iter:   40 | Time: 00:00:19 | Train Loss: 2.0505 | Average Loss: 2.2309
# Epoch:19 | Iter:   60 | Time: 00:00:19 | Train Loss: 2.0587 | Average Loss: 2.2285
# Accuracy: 0.674479 | Time: 00:00:00
# Epoch:20 | Iter:    0 | Time: 00:00:19 | Train Loss: 2.0490 | Average Loss: 2.2267
# Epoch:20 | Iter:   20 | Time: 00:00:19 | Train Loss: 2.0739 | Average Loss: 2.2244
# Epoch:20 | Iter:   40 | Time: 00:00:20 | Train Loss: 2.0407 | Average Loss: 2.2220
# Epoch:20 | Iter:   60 | Time: 00:00:20 | Train Loss: 2.0538 | Average Loss: 2.2197
# Accuracy: 0.692708 | Time: 00:00:00
# Epoch:21 | Iter:    0 | Time: 00:00:20 | Train Loss: 2.0605 | Average Loss: 2.2180
# Epoch:21 | Iter:   20 | Time: 00:00:20 | Train Loss: 2.0497 | Average Loss: 2.2158
# Epoch:21 | Iter:   40 | Time: 00:00:21 | Train Loss: 2.0335 | Average Loss: 2.2136
# Epoch:21 | Iter:   60 | Time: 00:00:21 | Train Loss: 2.0669 | Average Loss: 2.2114
# Accuracy: 0.700521 | Time: 00:00:00
# Epoch:22 | Iter:    0 | Time: 00:00:21 | Train Loss: 2.0411 | Average Loss: 2.2097
# Epoch:22 | Iter:   20 | Time: 00:00:22 | Train Loss: 2.0219 | Average Loss: 2.2076
# Epoch:22 | Iter:   40 | Time: 00:00:22 | Train Loss: 2.0189 | Average Loss: 2.2054
# Epoch:22 | Iter:   60 | Time: 00:00:22 | Train Loss: 2.0263 | Average Loss: 2.2032
# Accuracy: 0.697917 | Time: 00:00:00
# Epoch:23 | Iter:    0 | Time: 00:00:22 | Train Loss: 2.0254 | Average Loss: 2.2017
# Epoch:23 | Iter:   20 | Time: 00:00:23 | Train Loss: 2.0262 | Average Loss: 2.1996
# Epoch:23 | Iter:   40 | Time: 00:00:23 | Train Loss: 2.0170 | Average Loss: 2.1975
# Epoch:23 | Iter:   60 | Time: 00:00:23 | Train Loss: 2.0223 | Average Loss: 2.1955
# Accuracy: 0.742188 | Time: 00:00:00
# Epoch:24 | Iter:    0 | Time: 00:00:23 | Train Loss: 2.0190 | Average Loss: 2.1939
# Epoch:24 | Iter:   20 | Time: 00:00:24 | Train Loss: 2.0192 | Average Loss: 2.1919
# Epoch:24 | Iter:   40 | Time: 00:00:24 | Train Loss: 1.9987 | Average Loss: 2.1898
# Epoch:24 | Iter:   60 | Time: 00:00:24 | Train Loss: 2.0312 | Average Loss: 2.1879
# Accuracy: 0.716146 | Time: 00:00:00
# Epoch:25 | Iter:    0 | Time: 00:00:24 | Train Loss: 2.0079 | Average Loss: 2.1864
# Epoch:25 | Iter:   20 | Time: 00:00:25 | Train Loss: 1.9963 | Average Loss: 2.1845
# Epoch:25 | Iter:   40 | Time: 00:00:25 | Train Loss: 2.0052 | Average Loss: 2.1826
# Epoch:25 | Iter:   60 | Time: 00:00:25 | Train Loss: 2.0184 | Average Loss: 2.1807
# Accuracy: 0.721354 | Time: 00:00:00
# Epoch:26 | Iter:    0 | Time: 00:00:25 | Train Loss: 2.0063 | Average Loss: 2.1793
# Epoch:26 | Iter:   20 | Time: 00:00:26 | Train Loss: 2.0023 | Average Loss: 2.1774
# Epoch:26 | Iter:   40 | Time: 00:00:26 | Train Loss: 1.9888 | Average Loss: 2.1755
# Epoch:26 | Iter:   60 | Time: 00:00:26 | Train Loss: 2.0000 | Average Loss: 2.1736
# Accuracy: 0.723958 | Time: 00:00:00
# Epoch:27 | Iter:    0 | Time: 00:00:26 | Train Loss: 2.0113 | Average Loss: 2.1723
# Epoch:27 | Iter:   20 | Time: 00:00:27 | Train Loss: 1.9907 | Average Loss: 2.1705
# Epoch:27 | Iter:   40 | Time: 00:00:27 | Train Loss: 1.9896 | Average Loss: 2.1687
# Epoch:27 | Iter:   60 | Time: 00:00:27 | Train Loss: 1.9874 | Average Loss: 2.1670
# Accuracy: 0.731771 | Time: 00:00:00
# Epoch:28 | Iter:    0 | Time: 00:00:27 | Train Loss: 1.9951 | Average Loss: 2.1656
# Epoch:28 | Iter:   20 | Time: 00:00:28 | Train Loss: 1.9879 | Average Loss: 2.1639
# Epoch:28 | Iter:   40 | Time: 00:00:28 | Train Loss: 1.9699 | Average Loss: 2.1622
# Epoch:28 | Iter:   60 | Time: 00:00:28 | Train Loss: 2.0042 | Average Loss: 2.1605
# Accuracy: 0.695312 | Time: 00:00:00
# Epoch:29 | Iter:    0 | Time: 00:00:29 | Train Loss: 1.9974 | Average Loss: 2.1592
# Epoch:29 | Iter:   20 | Time: 00:00:29 | Train Loss: 1.9720 | Average Loss: 2.1576
# Epoch:29 | Iter:   40 | Time: 00:00:29 | Train Loss: 1.9805 | Average Loss: 2.1559
# Epoch:29 | Iter:   60 | Time: 00:00:29 | Train Loss: 1.9835 | Average Loss: 2.1543
# Accuracy: 0.695312 | Time: 00:00:00
# Epoch:30 | Iter:    0 | Time: 00:00:30 | Train Loss: 1.9744 | Average Loss: 2.1531
# Epoch:30 | Iter:   20 | Time: 00:00:30 | Train Loss: 1.9821 | Average Loss: 2.1515
# Epoch:30 | Iter:   40 | Time: 00:00:30 | Train Loss: 1.9773 | Average Loss: 2.1499
# Epoch:30 | Iter:   60 | Time: 00:00:30 | Train Loss: 1.9757 | Average Loss: 2.1483
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:31 | Iter:    0 | Time: 00:00:31 | Train Loss: 1.9739 | Average Loss: 2.1471
# Epoch:31 | Iter:   20 | Time: 00:00:31 | Train Loss: 1.9553 | Average Loss: 2.1456
# Epoch:31 | Iter:   40 | Time: 00:00:31 | Train Loss: 1.9599 | Average Loss: 2.1440
# Epoch:31 | Iter:   60 | Time: 00:00:31 | Train Loss: 1.9705 | Average Loss: 2.1425
# Accuracy: 0.705729 | Time: 00:00:00
# Epoch:32 | Iter:    0 | Time: 00:00:32 | Train Loss: 1.9806 | Average Loss: 2.1414
# Epoch:32 | Iter:   20 | Time: 00:00:32 | Train Loss: 1.9627 | Average Loss: 2.1400
# Epoch:32 | Iter:   40 | Time: 00:00:32 | Train Loss: 1.9632 | Average Loss: 2.1385
# Epoch:32 | Iter:   60 | Time: 00:00:32 | Train Loss: 1.9697 | Average Loss: 2.1370
# Accuracy: 0.713542 | Time: 00:00:00
# Epoch:33 | Iter:    0 | Time: 00:00:33 | Train Loss: 1.9617 | Average Loss: 2.1359
# Epoch:33 | Iter:   20 | Time: 00:00:33 | Train Loss: 1.9547 | Average Loss: 2.1345
# Epoch:33 | Iter:   40 | Time: 00:00:33 | Train Loss: 1.9525 | Average Loss: 2.1331
# Epoch:33 | Iter:   60 | Time: 00:00:33 | Train Loss: 1.9768 | Average Loss: 2.1317
# Accuracy: 0.731771 | Time: 00:00:00
# Epoch:34 | Iter:    0 | Time: 00:00:34 | Train Loss: 1.9647 | Average Loss: 2.1307
# Epoch:34 | Iter:   20 | Time: 00:00:34 | Train Loss: 1.9566 | Average Loss: 2.1293
# Epoch:34 | Iter:   40 | Time: 00:00:34 | Train Loss: 1.9439 | Average Loss: 2.1279
# Epoch:34 | Iter:   60 | Time: 00:00:34 | Train Loss: 1.9834 | Average Loss: 2.1266
# Accuracy: 0.713542 | Time: 00:00:00
# Epoch:35 | Iter:    0 | Time: 00:00:35 | Train Loss: 1.9579 | Average Loss: 2.1256
# Epoch:35 | Iter:   20 | Time: 00:00:35 | Train Loss: 1.9663 | Average Loss: 2.1243
# Epoch:35 | Iter:   40 | Time: 00:00:35 | Train Loss: 1.9435 | Average Loss: 2.1230
# Epoch:35 | Iter:   60 | Time: 00:00:36 | Train Loss: 1.9579 | Average Loss: 2.1217
# Accuracy: 0.692708 | Time: 00:00:00
# Epoch:36 | Iter:    0 | Time: 00:00:36 | Train Loss: 1.9521 | Average Loss: 2.1207
# Epoch:36 | Iter:   20 | Time: 00:00:36 | Train Loss: 1.9507 | Average Loss: 2.1195
# Epoch:36 | Iter:   40 | Time: 00:00:36 | Train Loss: 1.9392 | Average Loss: 2.1182
# Epoch:36 | Iter:   60 | Time: 00:00:37 | Train Loss: 1.9557 | Average Loss: 2.1169
# Accuracy: 0.682292 | Time: 00:00:00
# Epoch:37 | Iter:    0 | Time: 00:00:37 | Train Loss: 1.9486 | Average Loss: 2.1160
# Epoch:37 | Iter:   20 | Time: 00:00:37 | Train Loss: 1.9386 | Average Loss: 2.1148
# Epoch:37 | Iter:   40 | Time: 00:00:37 | Train Loss: 1.9499 | Average Loss: 2.1136
# Epoch:37 | Iter:   60 | Time: 00:00:38 | Train Loss: 1.9511 | Average Loss: 2.1124
# Accuracy: 0.710938 | Time: 00:00:00
# Epoch:38 | Iter:    0 | Time: 00:00:38 | Train Loss: 1.9410 | Average Loss: 2.1115
# Epoch:38 | Iter:   20 | Time: 00:00:38 | Train Loss: 1.9401 | Average Loss: 2.1103
# Epoch:38 | Iter:   40 | Time: 00:00:38 | Train Loss: 1.9413 | Average Loss: 2.1091
# Epoch:38 | Iter:   60 | Time: 00:00:39 | Train Loss: 1.9491 | Average Loss: 2.1079
# Accuracy: 0.690104 | Time: 00:00:00
# Epoch:39 | Iter:    0 | Time: 00:00:39 | Train Loss: 1.9403 | Average Loss: 2.1070
# Epoch:39 | Iter:   20 | Time: 00:00:39 | Train Loss: 1.9420 | Average Loss: 2.1059
# Epoch:39 | Iter:   40 | Time: 00:00:39 | Train Loss: 1.9319 | Average Loss: 2.1047
# Epoch:39 | Iter:   60 | Time: 00:00:40 | Train Loss: 1.9417 | Average Loss: 2.1036
# Accuracy: 0.752604 | Time: 00:00:00
# Epoch:40 | Iter:    0 | Time: 00:00:40 | Train Loss: 1.9399 | Average Loss: 2.1027
# Epoch:40 | Iter:   20 | Time: 00:00:40 | Train Loss: 1.9310 | Average Loss: 2.1016
# Epoch:40 | Iter:   40 | Time: 00:00:40 | Train Loss: 1.9339 | Average Loss: 2.1005
# Epoch:40 | Iter:   60 | Time: 00:00:41 | Train Loss: 1.9525 | Average Loss: 2.0994
# Accuracy: 0.669271 | Time: 00:00:00
# Epoch:41 | Iter:    0 | Time: 00:00:41 | Train Loss: 1.9448 | Average Loss: 2.0986
# Epoch:41 | Iter:   20 | Time: 00:00:41 | Train Loss: 1.9264 | Average Loss: 2.0975
# Epoch:41 | Iter:   40 | Time: 00:00:41 | Train Loss: 1.9199 | Average Loss: 2.0964
# Epoch:41 | Iter:   60 | Time: 00:00:42 | Train Loss: 1.9506 | Average Loss: 2.0953
# Accuracy: 0.695312 | Time: 00:00:00
# Epoch:42 | Iter:    0 | Time: 00:00:42 | Train Loss: 1.9271 | Average Loss: 2.0945
# Epoch:42 | Iter:   20 | Time: 00:00:42 | Train Loss: 1.9265 | Average Loss: 2.0935
# Epoch:42 | Iter:   40 | Time: 00:00:43 | Train Loss: 1.9184 | Average Loss: 2.0924
# Epoch:42 | Iter:   60 | Time: 00:00:43 | Train Loss: 1.9371 | Average Loss: 2.0914
# Accuracy: 0.703125 | Time: 00:00:00
# Epoch:43 | Iter:    0 | Time: 00:00:43 | Train Loss: 1.9356 | Average Loss: 2.0906
# Epoch:43 | Iter:   20 | Time: 00:00:43 | Train Loss: 1.9299 | Average Loss: 2.0896
# Epoch:43 | Iter:   40 | Time: 00:00:44 | Train Loss: 1.9228 | Average Loss: 2.0886
# Epoch:43 | Iter:   60 | Time: 00:00:44 | Train Loss: 1.9398 | Average Loss: 2.0876
# Accuracy: 0.723958 | Time: 00:00:00
# Epoch:44 | Iter:    0 | Time: 00:00:44 | Train Loss: 1.9212 | Average Loss: 2.0868
# Epoch:44 | Iter:   20 | Time: 00:00:44 | Train Loss: 1.9223 | Average Loss: 2.0859
# Epoch:44 | Iter:   40 | Time: 00:00:45 | Train Loss: 1.9164 | Average Loss: 2.0849
# Epoch:44 | Iter:   60 | Time: 00:00:45 | Train Loss: 1.9415 | Average Loss: 2.0839
# Accuracy: 0.755208 | Time: 00:00:00
# Epoch:45 | Iter:    0 | Time: 00:00:45 | Train Loss: 1.9271 | Average Loss: 2.0832
# Epoch:45 | Iter:   20 | Time: 00:00:45 | Train Loss: 1.9246 | Average Loss: 2.0822
# Epoch:45 | Iter:   40 | Time: 00:00:46 | Train Loss: 1.9150 | Average Loss: 2.0813
# Epoch:45 | Iter:   60 | Time: 00:00:46 | Train Loss: 1.9285 | Average Loss: 2.0803
# Accuracy: 0.703125 | Time: 00:00:00
# Epoch:46 | Iter:    0 | Time: 00:00:46 | Train Loss: 1.9194 | Average Loss: 2.0796
# Epoch:46 | Iter:   20 | Time: 00:00:46 | Train Loss: 1.9199 | Average Loss: 2.0787
# Epoch:46 | Iter:   40 | Time: 00:00:47 | Train Loss: 1.9199 | Average Loss: 2.0778
# Epoch:46 | Iter:   60 | Time: 00:00:47 | Train Loss: 1.9359 | Average Loss: 2.0769
# Accuracy: 0.690104 | Time: 00:00:00
# Epoch:47 | Iter:    0 | Time: 00:00:47 | Train Loss: 1.9203 | Average Loss: 2.0762
# Epoch:47 | Iter:   20 | Time: 00:00:47 | Train Loss: 1.9227 | Average Loss: 2.0753
# Epoch:47 | Iter:   40 | Time: 00:00:48 | Train Loss: 1.9127 | Average Loss: 2.0744
# Epoch:47 | Iter:   60 | Time: 00:00:48 | Train Loss: 1.9262 | Average Loss: 2.0735
# Accuracy: 0.744792 | Time: 00:00:00
# Epoch:48 | Iter:    0 | Time: 00:00:48 | Train Loss: 1.9134 | Average Loss: 2.0728
# Epoch:48 | Iter:   20 | Time: 00:00:48 | Train Loss: 1.9157 | Average Loss: 2.0720
# Epoch:48 | Iter:   40 | Time: 00:00:49 | Train Loss: 1.9126 | Average Loss: 2.0711
# Epoch:48 | Iter:   60 | Time: 00:00:49 | Train Loss: 1.9163 | Average Loss: 2.0702
# Accuracy: 0.742188 | Time: 00:00:00
# Epoch:49 | Iter:    0 | Time: 00:00:49 | Train Loss: 1.9114 | Average Loss: 2.0696
# Epoch:49 | Iter:   20 | Time: 00:00:50 | Train Loss: 1.9121 | Average Loss: 2.0688
# Epoch:49 | Iter:   40 | Time: 00:00:50 | Train Loss: 1.9107 | Average Loss: 2.0679
# Epoch:49 | Iter:   60 | Time: 00:00:50 | Train Loss: 1.9236 | Average Loss: 2.0671
# Accuracy: 0.731771 | Time: 00:00:00
# Epoch:50 | Iter:    0 | Time: 00:00:50 | Train Loss: 1.9146 | Average Loss: 2.0665
# Epoch:50 | Iter:   20 | Time: 00:00:51 | Train Loss: 1.9158 | Average Loss: 2.0656
# Epoch:50 | Iter:   40 | Time: 00:00:51 | Train Loss: 1.9062 | Average Loss: 2.0648
# Epoch:50 | Iter:   60 | Time: 00:00:51 | Train Loss: 1.9221 | Average Loss: 2.0640
# Accuracy: 0.736979 | Time: 00:00:00
# Epoch:51 | Iter:    0 | Time: 00:00:51 | Train Loss: 1.9089 | Average Loss: 2.0634
# Epoch:51 | Iter:   20 | Time: 00:00:52 | Train Loss: 1.9110 | Average Loss: 2.0626
# Epoch:51 | Iter:   40 | Time: 00:00:52 | Train Loss: 1.9152 | Average Loss: 2.0618
# Epoch:51 | Iter:   60 | Time: 00:00:52 | Train Loss: 1.9166 | Average Loss: 2.0610
# Accuracy: 0.750000 | Time: 00:00:00
# Epoch:52 | Iter:    0 | Time: 00:00:52 | Train Loss: 1.9125 | Average Loss: 2.0604
# Epoch:52 | Iter:   20 | Time: 00:00:53 | Train Loss: 1.9107 | Average Loss: 2.0596
# Epoch:52 | Iter:   40 | Time: 00:00:53 | Train Loss: 1.9036 | Average Loss: 2.0589
# Epoch:52 | Iter:   60 | Time: 00:00:53 | Train Loss: 1.9154 | Average Loss: 2.0581
# Accuracy: 0.721354 | Time: 00:00:00
# Epoch:53 | Iter:    0 | Time: 00:00:53 | Train Loss: 1.9075 | Average Loss: 2.0575
# Epoch:53 | Iter:   20 | Time: 00:00:54 | Train Loss: 1.9031 | Average Loss: 2.0568
# Epoch:53 | Iter:   40 | Time: 00:00:54 | Train Loss: 1.9031 | Average Loss: 2.0560
# Epoch:53 | Iter:   60 | Time: 00:00:54 | Train Loss: 1.9114 | Average Loss: 2.0553
# Accuracy: 0.703125 | Time: 00:00:00
# Epoch:54 | Iter:    0 | Time: 00:00:54 | Train Loss: 1.9108 | Average Loss: 2.0548
# Epoch:54 | Iter:   20 | Time: 00:00:55 | Train Loss: 1.9050 | Average Loss: 2.0540
# Epoch:54 | Iter:   40 | Time: 00:00:55 | Train Loss: 1.8995 | Average Loss: 2.0533
# Epoch:54 | Iter:   60 | Time: 00:00:55 | Train Loss: 1.9101 | Average Loss: 2.0526
# Accuracy: 0.700521 | Time: 00:00:00
# Epoch:55 | Iter:    0 | Time: 00:00:55 | Train Loss: 1.9058 | Average Loss: 2.0520
# Epoch:55 | Iter:   20 | Time: 00:00:56 | Train Loss: 1.9023 | Average Loss: 2.0513
# Epoch:55 | Iter:   40 | Time: 00:00:56 | Train Loss: 1.8994 | Average Loss: 2.0506
# Epoch:55 | Iter:   60 | Time: 00:00:56 | Train Loss: 1.9154 | Average Loss: 2.0499
# Accuracy: 0.703125 | Time: 00:00:00
# Epoch:56 | Iter:    0 | Time: 00:00:57 | Train Loss: 1.9168 | Average Loss: 2.0494
# Epoch:56 | Iter:   20 | Time: 00:00:57 | Train Loss: 1.9009 | Average Loss: 2.0487
# Epoch:56 | Iter:   40 | Time: 00:00:57 | Train Loss: 1.9000 | Average Loss: 2.0480
# Epoch:56 | Iter:   60 | Time: 00:00:58 | Train Loss: 1.9102 | Average Loss: 2.0474
# Accuracy: 0.729167 | Time: 00:00:00
# Epoch:57 | Iter:    0 | Time: 00:00:58 | Train Loss: 1.9058 | Average Loss: 2.0468
# Epoch:57 | Iter:   20 | Time: 00:00:58 | Train Loss: 1.9061 | Average Loss: 2.0462
# Epoch:57 | Iter:   40 | Time: 00:00:59 | Train Loss: 1.8935 | Average Loss: 2.0455
# Epoch:57 | Iter:   60 | Time: 00:00:59 | Train Loss: 1.9099 | Average Loss: 2.0448
# Accuracy: 0.695312 | Time: 00:00:00
# Epoch:58 | Iter:    0 | Time: 00:00:59 | Train Loss: 1.9009 | Average Loss: 2.0443
# Epoch:58 | Iter:   20 | Time: 00:00:59 | Train Loss: 1.9016 | Average Loss: 2.0437
# Epoch:58 | Iter:   40 | Time: 00:01:00 | Train Loss: 1.8958 | Average Loss: 2.0430
# Epoch:58 | Iter:   60 | Time: 00:01:00 | Train Loss: 1.9064 | Average Loss: 2.0424
# Accuracy: 0.708333 | Time: 00:00:00
# Epoch:59 | Iter:    0 | Time: 00:01:00 | Train Loss: 1.9015 | Average Loss: 2.0419
# Epoch:59 | Iter:   20 | Time: 00:01:00 | Train Loss: 1.8985 | Average Loss: 2.0413
# Epoch:59 | Iter:   40 | Time: 00:01:01 | Train Loss: 1.8985 | Average Loss: 2.0407
# Epoch:59 | Iter:   60 | Time: 00:01:01 | Train Loss: 1.9101 | Average Loss: 2.0400
# Accuracy: 0.697917 | Time: 00:00:00
# Epoch:60 | Iter:    0 | Time: 00:01:01 | Train Loss: 1.9002 | Average Loss: 2.0396
# Epoch:60 | Iter:   20 | Time: 00:01:01 | Train Loss: 1.9038 | Average Loss: 2.0390
# Epoch:60 | Iter:   40 | Time: 00:01:02 | Train Loss: 1.8937 | Average Loss: 2.0384
# Epoch:60 | Iter:   60 | Time: 00:01:02 | Train Loss: 1.9069 | Average Loss: 2.0377
# Accuracy: 0.700521 | Time: 00:00:00

# %% [markdown]
# **Answer**:
#
# Technique 3: Augmentation with deeper network and batchnormalization
#
# Data augmentation: Horizontal flipping
#
# Data normalization: First we calculated the mean and then subtracted from the image, which resulted in zero-centered image
#
# Layer 1: Convolution layer with 64 output channels, followed by batchnormalization, tanh activation and MaxPooling layer
#
# Layer 2: Convolution layer with 128 output channels, followed by batchnormalization, Sigmoid activation and MaxPooling layer
#
# Layer 3: NN layer with 4608 input node and 1024 output nodes. Batchnormalization and LeakyReLU is also added.
#
# Layer 4: NN layer with 1024 input and 16 output nodes. This is followed by batchnormalization and sigmoid activation. Dropout with p=0.5 was also added before this
#
# Accuracy on test set: **0.752604**
#
# Accuracy increases/decreases:

# %% [markdown]
# ## Problem 2: Fine Tuning a Pre-Trained Deep Network
# Our convolutional network to this point isn't "deep". Fortunately, the representations learned by deep convolutional networks is that they generalize surprisingly well to other recognition tasks.
#
# But how do we use an existing deep network for a new recognition task? Take for instance,  [AlexNet](http://papers.nips.cc/paper/4824-imagenet-classification-with-deep-convolutional-neural-networks) network has 1000 units in the final layer corresponding to 1000 ImageNet categories.
#
#
# **Hints**:
# - Many pre-trained models are available in PyTorch at [here](http://pytorch.org/docs/master/torchvision/models.html).
# - For fine-tuning pretrained network using PyTorch, please read this [tutorial](http://pytorch.org/tutorials/beginner/transfer_learning_tutorial.html).

# %% [markdown]
# ### Problem 2.1
#
# **Strategy A**: *Fine-tune* an existing network. In this scenario you take an existing network, replace the final layer (or more) with random weights, and train the entire network again with images and ground truth labels for your recognition task. You are effectively treating the pre-trained deep network as a better initialization than the random weights used when training from scratch. When you don't have enough training data to train a complex network from scratch (e.g. with the 16 classes) this is an attractive option. Fine-tuning can work far better than Strategy B of taking the activations directly from an pre-trained CNN. For example, in [this paper](http://www.cc.gatech.edu/~hays/papers/deep_geo.pdf) from CVPR 2015, there wasn't enough data to train a deep network from scratch, but fine tuning led to 4 times higher accuracy than using off-the-shelf networks directly.
#
# (25 points) You are required to implement Strategy A to fine-tune a pre-trained **AlexNet** for this scene classification task. You should be able to achieve accuracy of **0.85** approximately. The minimum accuracy required for this section is **0.75**.
#
# Please provide detailed descriptions of:<br>
# (1) which layers of AlexNet have been replaced<br>
# (2) the architecture of the new layers added including activation methods (same as problem 1)<br>
# (3) the final accuracy on test set <br>

# %%
# reload data with a larger size
img_size = (224, 224)
batch_size = 64 # training sample number per batch 

# load training dataset
trainloader_large = list(load_dataset('./data/train/', img_size, batch_size=batch_size, shuffle=True, 
                                      augment=False, is_color=True, zero_centered=True))
train_num = len(trainloader_large)
print("Finish loading %d minibatches (batch_size=%d) of training samples." % (train_num, batch_size))

# load testing dataset
testloader_large = list(load_dataset('./data/test/', img_size, num_per_class=50, batch_size=batch_size, is_color=True, zero_centered=True))
test_num = len(testloader_large)
print("Finish loading %d minibatches (batch_size=%d) of testing samples." % (test_num, batch_size))
# Out:
# Loading images from class: 0
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:43: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 37 minibatches (batch_size=64) of training samples.
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 6 minibatches (batch_size=64) of testing samples.

# %%
#--------------------------------------------------
#       Fine-Tune Pretrained Network
#--------------------------------------------------
from torchvision import models
pretrained_net = models.alexnet(pretrained = True)


class Iden(nn.Module):
  def __init__(self):
    super(Iden,self).__init__()

  def forward(self,x):
    return x



class HorNet(nn.Module):
    def __init__(self):
      super(HorNet,self).__init__()  
           
      self.classifier = nn.Sequential(
          nn.Dropout(0.25),
          nn.Linear(9216, 4096), 
          nn.BatchNorm1d(4096),
          nn.ReLU(),
          nn.Dropout(0.25),
          nn.Linear(4096, 1024),
          nn.ReLU(),
          nn.Dropout(0.5),
          nn.Linear(1024,16),
      )
      
    def forward(self, x):
      x = self.classifier(x)
      return x  

pretrained_net.avgpool = Iden()
pretrained_net.classifier = HorNet()

# %%
#--------------------------------------------------
#       Start Training & Evaluation
#--------------------------------------------------
net = pretrained_net
train_option = {}
train_option['lr'] = 0.002
train_option['epoch'] = 40
train_option['device'] = 'gpu'
train_option['optimizer'] = optim.SGD(net.parameters(), lr=0.01, momentum=0.9)
trainModel(net, trainloader_large, train_option, testloader_large)
# Out:
# Epoch: 1 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.8407 | Average Loss: 2.8407
# Epoch: 1 | Iter:   20 | Time: 00:00:02 | Train Loss: 0.8601 | Average Loss: 1.9679
# Accuracy: 0.763021 | Time: 00:00:00
# Epoch: 2 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.6591 | Average Loss: 1.4353
# Epoch: 2 | Iter:   20 | Time: 00:00:05 | Train Loss: 0.4108 | Average Loss: 1.1207
# Accuracy: 0.752604 | Time: 00:00:00
# Epoch: 3 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.3808 | Average Loss: 0.9646
# Epoch: 3 | Iter:   20 | Time: 00:00:09 | Train Loss: 0.2062 | Average Loss: 0.8241
# Accuracy: 0.802083 | Time: 00:00:00
# Epoch: 4 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.1794 | Average Loss: 0.7350
# Epoch: 4 | Iter:   20 | Time: 00:00:13 | Train Loss: 0.0879 | Average Loss: 0.6487
# Accuracy: 0.812500 | Time: 00:00:00
# Epoch: 5 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.2642 | Average Loss: 0.5917
# Epoch: 5 | Iter:   20 | Time: 00:00:17 | Train Loss: 0.0465 | Average Loss: 0.5345
# Accuracy: 0.835938 | Time: 00:00:00
# Epoch: 6 | Iter:    0 | Time: 00:00:19 | Train Loss: 0.0535 | Average Loss: 0.4961
# Epoch: 6 | Iter:   20 | Time: 00:00:21 | Train Loss: 0.0264 | Average Loss: 0.4541
# Accuracy: 0.815104 | Time: 00:00:00
# Epoch: 7 | Iter:    0 | Time: 00:00:22 | Train Loss: 0.0590 | Average Loss: 0.4233
# Epoch: 7 | Iter:   20 | Time: 00:00:24 | Train Loss: 0.0069 | Average Loss: 0.3926
# Accuracy: 0.770833 | Time: 00:00:00
# Epoch: 8 | Iter:    0 | Time: 00:00:26 | Train Loss: 0.0610 | Average Loss: 0.3699
# Epoch: 8 | Iter:   20 | Time: 00:00:28 | Train Loss: 0.0467 | Average Loss: 0.3455
# Accuracy: 0.799479 | Time: 00:00:00
# Epoch: 9 | Iter:    0 | Time: 00:00:30 | Train Loss: 0.0605 | Average Loss: 0.3281
# Epoch: 9 | Iter:   20 | Time: 00:00:32 | Train Loss: 0.0071 | Average Loss: 0.3085
# Accuracy: 0.812500 | Time: 00:00:00
# Epoch:10 | Iter:    0 | Time: 00:00:34 | Train Loss: 0.0447 | Average Loss: 0.2941
# Epoch:10 | Iter:   20 | Time: 00:00:36 | Train Loss: 0.0184 | Average Loss: 0.2783
# Accuracy: 0.809896 | Time: 00:00:00
# Epoch:11 | Iter:    0 | Time: 00:00:38 | Train Loss: 0.0024 | Average Loss: 0.2661
# Epoch:11 | Iter:   20 | Time: 00:00:39 | Train Loss: 0.0107 | Average Loss: 0.2529
# Accuracy: 0.822917 | Time: 00:00:00
# Epoch:12 | Iter:    0 | Time: 00:00:41 | Train Loss: 0.0137 | Average Loss: 0.2429
# Epoch:12 | Iter:   20 | Time: 00:00:43 | Train Loss: 0.0053 | Average Loss: 0.2324
# Accuracy: 0.802083 | Time: 00:00:00
# Epoch:13 | Iter:    0 | Time: 00:00:45 | Train Loss: 0.0007 | Average Loss: 0.2238
# Epoch:13 | Iter:   20 | Time: 00:00:47 | Train Loss: 0.0048 | Average Loss: 0.2146
# Accuracy: 0.815104 | Time: 00:00:00
# Epoch:14 | Iter:    0 | Time: 00:00:49 | Train Loss: 0.0016 | Average Loss: 0.2075
# Epoch:14 | Iter:   20 | Time: 00:00:51 | Train Loss: 0.0315 | Average Loss: 0.1998
# Accuracy: 0.820312 | Time: 00:00:00
# Epoch:15 | Iter:    0 | Time: 00:00:53 | Train Loss: 0.0021 | Average Loss: 0.1938
# Epoch:15 | Iter:   20 | Time: 00:00:55 | Train Loss: 0.0033 | Average Loss: 0.1867
# Accuracy: 0.854167 | Time: 00:00:00
# Epoch:16 | Iter:    0 | Time: 00:00:57 | Train Loss: 0.0017 | Average Loss: 0.1812
# Epoch:16 | Iter:   20 | Time: 00:00:59 | Train Loss: 0.0038 | Average Loss: 0.1751
# Accuracy: 0.822917 | Time: 00:00:00
# Epoch:17 | Iter:    0 | Time: 00:01:01 | Train Loss: 0.0075 | Average Loss: 0.1705
# Epoch:17 | Iter:   20 | Time: 00:01:03 | Train Loss: 0.0042 | Average Loss: 0.1652
# Accuracy: 0.846354 | Time: 00:00:00
# Epoch:18 | Iter:    0 | Time: 00:01:04 | Train Loss: 0.0020 | Average Loss: 0.1608
# Epoch:18 | Iter:   20 | Time: 00:01:06 | Train Loss: 0.0012 | Average Loss: 0.1560
# Accuracy: 0.851562 | Time: 00:00:00
# Epoch:19 | Iter:    0 | Time: 00:01:08 | Train Loss: 0.0018 | Average Loss: 0.1521
# Epoch:19 | Iter:   20 | Time: 00:01:10 | Train Loss: 0.0052 | Average Loss: 0.1477
# Accuracy: 0.854167 | Time: 00:00:00
# Epoch:20 | Iter:    0 | Time: 00:01:12 | Train Loss: 0.0003 | Average Loss: 0.1441
# Epoch:20 | Iter:   20 | Time: 00:01:14 | Train Loss: 0.0007 | Average Loss: 0.1402
# Accuracy: 0.843750 | Time: 00:00:00
# Epoch:21 | Iter:    0 | Time: 00:01:16 | Train Loss: 0.0001 | Average Loss: 0.1370
# Epoch:21 | Iter:   20 | Time: 00:01:18 | Train Loss: 0.0002 | Average Loss: 0.1334
# Accuracy: 0.851562 | Time: 00:00:00
# Epoch:22 | Iter:    0 | Time: 00:01:20 | Train Loss: 0.0002 | Average Loss: 0.1305
# Epoch:22 | Iter:   20 | Time: 00:01:21 | Train Loss: 0.0002 | Average Loss: 0.1273
# Accuracy: 0.861979 | Time: 00:00:00
# Epoch:23 | Iter:    0 | Time: 00:01:23 | Train Loss: 0.0001 | Average Loss: 0.1246
# Epoch:23 | Iter:   20 | Time: 00:01:25 | Train Loss: 0.0002 | Average Loss: 0.1217
# Accuracy: 0.856771 | Time: 00:00:00
# Epoch:24 | Iter:    0 | Time: 00:01:27 | Train Loss: 0.0001 | Average Loss: 0.1193
# Epoch:24 | Iter:   20 | Time: 00:01:29 | Train Loss: 0.0002 | Average Loss: 0.1165
# Accuracy: 0.856771 | Time: 00:00:00
# Epoch:25 | Iter:    0 | Time: 00:01:31 | Train Loss: 0.0001 | Average Loss: 0.1143
# Epoch:25 | Iter:   20 | Time: 00:01:33 | Train Loss: 0.0008 | Average Loss: 0.1118
# Accuracy: 0.861979 | Time: 00:00:00
# Epoch:26 | Iter:    0 | Time: 00:01:35 | Train Loss: 0.0002 | Average Loss: 0.1098
# Epoch:26 | Iter:   20 | Time: 00:01:37 | Train Loss: 0.0004 | Average Loss: 0.1075
# Accuracy: 0.864583 | Time: 00:00:00
# Epoch:27 | Iter:    0 | Time: 00:01:38 | Train Loss: 0.0001 | Average Loss: 0.1056
# Epoch:27 | Iter:   20 | Time: 00:01:40 | Train Loss: 0.0002 | Average Loss: 0.1034
# Accuracy: 0.856771 | Time: 00:00:00
# Epoch:28 | Iter:    0 | Time: 00:01:42 | Train Loss: 0.0002 | Average Loss: 0.1017
# Epoch:28 | Iter:   20 | Time: 00:01:44 | Train Loss: 0.0001 | Average Loss: 0.0997
# Accuracy: 0.856771 | Time: 00:00:00
# Epoch:29 | Iter:    0 | Time: 00:01:46 | Train Loss: 0.0001 | Average Loss: 0.0981
# Epoch:29 | Iter:   20 | Time: 00:01:48 | Train Loss: 0.0003 | Average Loss: 0.0962
# Accuracy: 0.846354 | Time: 00:00:00
# Epoch:30 | Iter:    0 | Time: 00:01:50 | Train Loss: 0.0001 | Average Loss: 0.0947
# Epoch:30 | Iter:   20 | Time: 00:01:52 | Train Loss: 0.0001 | Average Loss: 0.0930
# Accuracy: 0.856771 | Time: 00:00:00
# Epoch:31 | Iter:    0 | Time: 00:01:54 | Train Loss: 0.0000 | Average Loss: 0.0915
# Epoch:31 | Iter:   20 | Time: 00:01:56 | Train Loss: 0.0001 | Average Loss: 0.0899
# Accuracy: 0.856771 | Time: 00:00:00
# Epoch:32 | Iter:    0 | Time: 00:01:57 | Train Loss: 0.0001 | Average Loss: 0.0886
# Epoch:32 | Iter:   20 | Time: 00:01:59 | Train Loss: 0.0001 | Average Loss: 0.0871
# Accuracy: 0.861979 | Time: 00:00:00
# Epoch:33 | Iter:    0 | Time: 00:02:01 | Train Loss: 0.0001 | Average Loss: 0.0858
# Epoch:33 | Iter:   20 | Time: 00:02:03 | Train Loss: 0.0001 | Average Loss: 0.0844
# Accuracy: 0.859375 | Time: 00:00:00
# Epoch:34 | Iter:    0 | Time: 00:02:05 | Train Loss: 0.0001 | Average Loss: 0.0832
# Epoch:34 | Iter:   20 | Time: 00:02:07 | Train Loss: 0.0002 | Average Loss: 0.0819
# Accuracy: 0.859375 | Time: 00:00:00
# Epoch:35 | Iter:    0 | Time: 00:02:09 | Train Loss: 0.0002 | Average Loss: 0.0808
# Epoch:35 | Iter:   20 | Time: 00:02:11 | Train Loss: 0.0002 | Average Loss: 0.0795
# Accuracy: 0.856771 | Time: 00:00:00
# Epoch:36 | Iter:    0 | Time: 00:02:12 | Train Loss: 0.0001 | Average Loss: 0.0785
# Epoch:36 | Iter:   20 | Time: 00:02:14 | Train Loss: 0.0001 | Average Loss: 0.0773
# Accuracy: 0.851562 | Time: 00:00:00
# Epoch:37 | Iter:    0 | Time: 00:02:16 | Train Loss: 0.0001 | Average Loss: 0.0763
# Epoch:37 | Iter:   20 | Time: 00:02:18 | Train Loss: 0.0001 | Average Loss: 0.0752
# Accuracy: 0.856771 | Time: 00:00:00
# Epoch:38 | Iter:    0 | Time: 00:02:20 | Train Loss: 0.0001 | Average Loss: 0.0743
# Epoch:38 | Iter:   20 | Time: 00:02:22 | Train Loss: 0.0001 | Average Loss: 0.0732
# Accuracy: 0.854167 | Time: 00:00:00
# Epoch:39 | Iter:    0 | Time: 00:02:24 | Train Loss: 0.0002 | Average Loss: 0.0723
# Epoch:39 | Iter:   20 | Time: 00:02:26 | Train Loss: 0.0002 | Average Loss: 0.0713
# Accuracy: 0.851562 | Time: 00:00:00
# Epoch:40 | Iter:    0 | Time: 00:02:28 | Train Loss: 0.0001 | Average Loss: 0.0705
# Epoch:40 | Iter:   20 | Time: 00:02:29 | Train Loss: 0.0001 | Average Loss: 0.0695
# Accuracy: 0.854167 | Time: 00:00:00

# %% [markdown]
# **Answer**:
#
# (1) which layers of AlexNet have been replaced
#
# The global avg. pooling layer and the final classification layer
#
# (2) the architecture of the new layers added including activation methods (same as problem 1)
#
# Data augmentation: Yes
#
# Data normalization: Yes
#
# Features Layers :
#
# (features): Sequential(
#
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#
#     (1): ReLU(inplace=True)
#
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#
#     (4): ReLU(inplace=True)
#
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#
#     (7): ReLU(inplace=True)
#
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#
#     (9): ReLU(inplace=True)
#
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#
#     (11): ReLU(inplace=True)
#
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#
# Classifier Layer:
#
#   (classifier): HorNet(
#
#     (classifier): Sequential(
#       (0): Dropout(p=0.25, inplace=False)
#       (1): Linear(in_features=9216, out_features=4096, bias=True)
#       (2): BatchNorm1d(4096, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): ReLU()
#       (4): Dropout(p=0.25, inplace=False)
#       (5): Linear(in_features=4096, out_features=1024, bias=True)
#       (6): ReLU()
#       (7): Dropout(p=0.5, inplace=False)
#       (8): Linear(in_features=1024, out_features=16, bias=True)
#     )
#   )
#
#
# (3) the final accuracy on test set
#
# Accuracy on test set: **0.861979**

# %% [markdown]
# ### Problem 2.2
# **Strategy B**: One could use those 1000 activations as a feature in place of a hand crafted feature such as a bag-of-features representation. You would train a classifier (typically a linear SVM) in that 1000 dimensional feature space. However, those activations are clearly very object specific and may not generalize well to new recognition tasks. It is generally better to use the activations in slightly earlier layers of the network, e.g. the 4096 activations in the last 2nd fully-connected layer. You can often get away with sub-sampling those 4096 activations considerably, e.g. taking only the first 1000 activations.
#
# (25 points) Implement Strategy B where you use the activations of the pre-trained **AlexNet** as features to train **one-vs-all SVMs** for your scene classification task. Report the final accuracy on test set. You should be able to achieve accuracy of **0.80** approximately. The minimum accuracy required for this section is **0.70**.

# %%
#--------------------------------------------------
#       Get Features from AlexNet
#--------------------------------------------------
def get_features(model , dataset):
  
  act = {}
  feature_train = None
  label_train = None
  def activation(name):
    def hook(model, input, output):
        act[name] = output.detach()
    return hook

  model.classifier[5].register_forward_hook(activation('ReLU_layer'))

  model = model.cuda()
  for iter, (i, l) in enumerate(dataset):
    i_batch = Variable(i).float().cuda()
    l_batch = Variable(l).long().cuda()
    
    outputs = model(i_batch)
    if feature_train is None :
      feature_train = act[ 'ReLU_layer' ][:,:1000]
      label_train = l_batch
    else :
      feature_train = torch.vstack((feature_train, act['ReLU_layer'][:,:1000]))
      label_train = torch.vstack((label_train,l_batch))
  
  label_train = label_train.view(-1,1)
  
  return feature_train, label_train

pretrained_net = models.alexnet(pretrained=True)

train_feat, train_label = get_features(pretrained_net, trainloader_large)
test_feat, test_label = get_features(pretrained_net, testloader_large)
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
#--------------------------------------------------
#       Train and Evaluate SVM
#--------------------------------------------------
from sklearn.multiclass import OneVsOneClassifier
from sklearn.svm import LinearSVC
train_feat, train_label = train_feat.detach().cpu().numpy() ,train_label.detach().cpu().numpy().ravel()
test_feat, test_label = test_feat.detach().cpu().numpy() ,test_label.detach().cpu().numpy().ravel()

clf = OneVsOneClassifier(LinearSVC(random_state=0)).fit(train_feat, train_label)

pred = [-1]*len(test_feat)
for k in range(len(test_feat)):
  pred[k] = clf.predict(np.reshape(test_feat[k],(1,-1)))

test_pred = np.reshape(np.array(pred),(-1,))

acc = sum(np.array(test_pred) == test_label) / float(len(test_label))
print("SVM accuracy {:.2f}%".format(acc*100))
# Out:
# SVM accuracy 75.00%

# %% [markdown]
# **Answer**:
#
# Accuracy on test set: **75.00%**

# %% [markdown]
# ### Problem 2.3 (Bonus)
#
# (Bonus: 10 points) Bonus will be given to those who fine-tune the [ResNet network](https://pytorch.org/docs/stable/_modules/torchvision/models/resnet.html) [(paper)](https://arxiv.org/abs/1512.03385) and compare performance with AlexNet. Explain why ResNet performed better or worse. You are **required** to use **resnet50** model. You should be able to achieve accuracy of **0.99** approximately. The minimum accuracy required for this section is **0.85**.

# %%
#--------------------------------------------------
#       Fine-Tune Pretrained Network
#--------------------------------------------------
pretrained_net = models.resnet50(pretrained = True)
pretrained_net.fc = nn.Sequential(nn.BatchNorm1d(2048),
                         nn.Dropout(0.5),
                         nn.Linear(2048,1000,bias=True),
                         nn.ReLU(),
                         nn.Linear(1000,16))

net = pretrained_net
train_option = {}
train_option['lr'] = 0.002
train_option['epoch'] = 40
train_option['device'] = 'gpu'
train_option['optimizer'] = optim.SGD(net.parameters(), lr=0.01, momentum=0.9)
trainModel(net, trainloader_large, train_option, testloader_large)
# Out:
# Epoch: 1 | Iter:    0 | Time: 00:00:01 | Train Loss: 2.8661 | Average Loss: 2.8661
# Epoch: 1 | Iter:   20 | Time: 00:00:14 | Train Loss: 0.2724 | Average Loss: 1.5355
# Accuracy: 0.841146 | Time: 00:00:00
# Epoch: 2 | Iter:    0 | Time: 00:00:26 | Train Loss: 0.2188 | Average Loss: 1.0158
# Epoch: 2 | Iter:   20 | Time: 00:00:39 | Train Loss: 0.1807 | Average Loss: 0.7575
# Accuracy: 0.820312 | Time: 00:00:00
# Epoch: 3 | Iter:    0 | Time: 00:00:52 | Train Loss: 0.1598 | Average Loss: 0.6136
# Epoch: 3 | Iter:   20 | Time: 00:01:05 | Train Loss: 0.0158 | Average Loss: 0.5024
# Accuracy: 0.898438 | Time: 00:00:00
# Epoch: 4 | Iter:    0 | Time: 00:01:18 | Train Loss: 0.0213 | Average Loss: 0.4322
# Epoch: 4 | Iter:   20 | Time: 00:01:31 | Train Loss: 0.0043 | Average Loss: 0.3712
# Accuracy: 0.921875 | Time: 00:00:00
# Epoch: 5 | Iter:    0 | Time: 00:01:44 | Train Loss: 0.0423 | Average Loss: 0.3310
# Epoch: 5 | Iter:   20 | Time: 00:01:58 | Train Loss: 0.0016 | Average Loss: 0.2938
# Accuracy: 0.898438 | Time: 00:00:00
# Epoch: 6 | Iter:    0 | Time: 00:02:11 | Train Loss: 0.0105 | Average Loss: 0.2680
# Epoch: 6 | Iter:   20 | Time: 00:02:24 | Train Loss: 0.0807 | Average Loss: 0.2440
# Accuracy: 0.864583 | Time: 00:00:01
# Epoch: 7 | Iter:    0 | Time: 00:02:37 | Train Loss: 0.0380 | Average Loss: 0.2272
# Epoch: 7 | Iter:   20 | Time: 00:02:51 | Train Loss: 0.0042 | Average Loss: 0.2099
# Accuracy: 0.869792 | Time: 00:00:01
# Epoch: 8 | Iter:    0 | Time: 00:03:04 | Train Loss: 0.0693 | Average Loss: 0.1985
# Epoch: 8 | Iter:   20 | Time: 00:03:19 | Train Loss: 0.0201 | Average Loss: 0.1861
# Accuracy: 0.911458 | Time: 00:00:01
# Epoch: 9 | Iter:    0 | Time: 00:03:32 | Train Loss: 0.0095 | Average Loss: 0.1762
# Epoch: 9 | Iter:   20 | Time: 00:03:46 | Train Loss: 0.0306 | Average Loss: 0.1660
# Accuracy: 0.895833 | Time: 00:00:01
# Epoch:10 | Iter:    0 | Time: 00:03:59 | Train Loss: 0.0075 | Average Loss: 0.1579
# Epoch:10 | Iter:   20 | Time: 00:04:13 | Train Loss: 0.0012 | Average Loss: 0.1491
# Accuracy: 0.908854 | Time: 00:00:01
# Epoch:11 | Iter:    0 | Time: 00:04:26 | Train Loss: 0.0004 | Average Loss: 0.1424
# Epoch:11 | Iter:   20 | Time: 00:04:40 | Train Loss: 0.0050 | Average Loss: 0.1353
# Accuracy: 0.908854 | Time: 00:00:01
# Epoch:12 | Iter:    0 | Time: 00:04:53 | Train Loss: 0.0008 | Average Loss: 0.1299
# Epoch:12 | Iter:   20 | Time: 00:05:07 | Train Loss: 0.0004 | Average Loss: 0.1241
# Accuracy: 0.880208 | Time: 00:00:01
# Epoch:13 | Iter:    0 | Time: 00:05:20 | Train Loss: 0.1412 | Average Loss: 0.1204
# Epoch:13 | Iter:   20 | Time: 00:05:34 | Train Loss: 0.0511 | Average Loss: 0.1171
# Accuracy: 0.890625 | Time: 00:00:01
# Epoch:14 | Iter:    0 | Time: 00:05:47 | Train Loss: 0.0174 | Average Loss: 0.1136
# Epoch:14 | Iter:   20 | Time: 00:06:02 | Train Loss: 0.0434 | Average Loss: 0.1094
# Accuracy: 0.893229 | Time: 00:00:01
# Epoch:15 | Iter:    0 | Time: 00:06:15 | Train Loss: 0.0005 | Average Loss: 0.1064
# Epoch:15 | Iter:   20 | Time: 00:06:29 | Train Loss: 0.0005 | Average Loss: 0.1028
# Accuracy: 0.921875 | Time: 00:00:01
# Epoch:16 | Iter:    0 | Time: 00:06:42 | Train Loss: 0.0008 | Average Loss: 0.0998
# Epoch:16 | Iter:   20 | Time: 00:06:56 | Train Loss: 0.0009 | Average Loss: 0.0963
# Accuracy: 0.929688 | Time: 00:00:01
# Epoch:17 | Iter:    0 | Time: 00:07:09 | Train Loss: 0.0006 | Average Loss: 0.0936
# Epoch:17 | Iter:   20 | Time: 00:07:23 | Train Loss: 0.0003 | Average Loss: 0.0906
# Accuracy: 0.929688 | Time: 00:00:01
# Epoch:18 | Iter:    0 | Time: 00:07:36 | Train Loss: 0.0004 | Average Loss: 0.0881
# Epoch:18 | Iter:   20 | Time: 00:07:50 | Train Loss: 0.0002 | Average Loss: 0.0854
# Accuracy: 0.929688 | Time: 00:00:01
# Epoch:19 | Iter:    0 | Time: 00:08:03 | Train Loss: 0.0002 | Average Loss: 0.0833
# Epoch:19 | Iter:   20 | Time: 00:08:17 | Train Loss: 0.0002 | Average Loss: 0.0809
# Accuracy: 0.929688 | Time: 00:00:01
# Epoch:20 | Iter:    0 | Time: 00:08:30 | Train Loss: 0.0003 | Average Loss: 0.0789
# Epoch:20 | Iter:   20 | Time: 00:08:45 | Train Loss: 0.0001 | Average Loss: 0.0767
# Accuracy: 0.929688 | Time: 00:00:01
# Epoch:21 | Iter:    0 | Time: 00:08:58 | Train Loss: 0.0002 | Average Loss: 0.0750
# Epoch:21 | Iter:   20 | Time: 00:09:12 | Train Loss: 0.0001 | Average Loss: 0.0730
# Accuracy: 0.932292 | Time: 00:00:01
# Epoch:22 | Iter:    0 | Time: 00:09:25 | Train Loss: 0.0002 | Average Loss: 0.0714
# Epoch:22 | Iter:   20 | Time: 00:09:39 | Train Loss: 0.0001 | Average Loss: 0.0696
# Accuracy: 0.932292 | Time: 00:00:01
# Epoch:23 | Iter:    0 | Time: 00:09:52 | Train Loss: 0.0002 | Average Loss: 0.0682
# Epoch:23 | Iter:   20 | Time: 00:10:06 | Train Loss: 0.0001 | Average Loss: 0.0666
# Accuracy: 0.932292 | Time: 00:00:01
# Epoch:24 | Iter:    0 | Time: 00:10:19 | Train Loss: 0.0002 | Average Loss: 0.0652
# Epoch:24 | Iter:   20 | Time: 00:10:33 | Train Loss: 0.0001 | Average Loss: 0.0638
# Accuracy: 0.929688 | Time: 00:00:01
# Epoch:25 | Iter:    0 | Time: 00:10:47 | Train Loss: 0.0002 | Average Loss: 0.0625
# Epoch:25 | Iter:   20 | Time: 00:11:01 | Train Loss: 0.0001 | Average Loss: 0.0612
# Accuracy: 0.929688 | Time: 00:00:01
# Epoch:26 | Iter:    0 | Time: 00:11:14 | Train Loss: 0.0002 | Average Loss: 0.0600
# Epoch:26 | Iter:   20 | Time: 00:11:28 | Train Loss: 0.0001 | Average Loss: 0.0588
# Accuracy: 0.929688 | Time: 00:00:01
# Epoch:27 | Iter:    0 | Time: 00:11:41 | Train Loss: 0.0001 | Average Loss: 0.0577
# Epoch:27 | Iter:   20 | Time: 00:11:55 | Train Loss: 0.0001 | Average Loss: 0.0566
# Accuracy: 0.929688 | Time: 00:00:01
# Epoch:28 | Iter:    0 | Time: 00:12:08 | Train Loss: 0.0001 | Average Loss: 0.0556
# Epoch:28 | Iter:   20 | Time: 00:12:22 | Train Loss: 0.0001 | Average Loss: 0.0545
# Accuracy: 0.929688 | Time: 00:00:01
# Epoch:29 | Iter:    0 | Time: 00:12:35 | Train Loss: 0.0001 | Average Loss: 0.0536
# Epoch:29 | Iter:   20 | Time: 00:12:49 | Train Loss: 0.0001 | Average Loss: 0.0526
# Accuracy: 0.929688 | Time: 00:00:01
# Epoch:30 | Iter:    0 | Time: 00:13:02 | Train Loss: 0.0001 | Average Loss: 0.0518
# Epoch:30 | Iter:   20 | Time: 00:13:16 | Train Loss: 0.0001 | Average Loss: 0.0509
# Accuracy: 0.927083 | Time: 00:00:01
# Epoch:31 | Iter:    0 | Time: 00:13:30 | Train Loss: 0.0001 | Average Loss: 0.0501
# Epoch:31 | Iter:   20 | Time: 00:13:44 | Train Loss: 0.0001 | Average Loss: 0.0492
# Accuracy: 0.927083 | Time: 00:00:01
# Epoch:32 | Iter:    0 | Time: 00:13:57 | Train Loss: 0.0001 | Average Loss: 0.0485
# Epoch:32 | Iter:   20 | Time: 00:14:11 | Train Loss: 0.0001 | Average Loss: 0.0476
# Accuracy: 0.927083 | Time: 00:00:01
# Epoch:33 | Iter:    0 | Time: 00:14:24 | Train Loss: 0.0001 | Average Loss: 0.0470
# Epoch:33 | Iter:   20 | Time: 00:14:38 | Train Loss: 0.0001 | Average Loss: 0.0462
# Accuracy: 0.927083 | Time: 00:00:01
# Epoch:34 | Iter:    0 | Time: 00:14:51 | Train Loss: 0.0001 | Average Loss: 0.0455
# Epoch:34 | Iter:   20 | Time: 00:15:05 | Train Loss: 0.0001 | Average Loss: 0.0448
# Accuracy: 0.927083 | Time: 00:00:01
# Epoch:35 | Iter:    0 | Time: 00:15:19 | Train Loss: 0.0001 | Average Loss: 0.0442
# Epoch:35 | Iter:   20 | Time: 00:15:33 | Train Loss: 0.0001 | Average Loss: 0.0435
# Accuracy: 0.927083 | Time: 00:00:01
# Epoch:36 | Iter:    0 | Time: 00:15:46 | Train Loss: 0.0001 | Average Loss: 0.0429
# Epoch:36 | Iter:   20 | Time: 00:16:00 | Train Loss: 0.0001 | Average Loss: 0.0423
# Accuracy: 0.927083 | Time: 00:00:01
# Epoch:37 | Iter:    0 | Time: 00:16:13 | Train Loss: 0.0001 | Average Loss: 0.0418
# Epoch:37 | Iter:   20 | Time: 00:16:27 | Train Loss: 0.0000 | Average Loss: 0.0411
# Accuracy: 0.927083 | Time: 00:00:01
# Epoch:38 | Iter:    0 | Time: 00:16:40 | Train Loss: 0.0001 | Average Loss: 0.0406
# Epoch:38 | Iter:   20 | Time: 00:16:54 | Train Loss: 0.0001 | Average Loss: 0.0400
# Accuracy: 0.927083 | Time: 00:00:01
# Epoch:39 | Iter:    0 | Time: 00:17:07 | Train Loss: 0.0001 | Average Loss: 0.0396
# Epoch:39 | Iter:   20 | Time: 00:17:21 | Train Loss: 0.0000 | Average Loss: 0.0390
# Accuracy: 0.927083 | Time: 00:00:01
# Epoch:40 | Iter:    0 | Time: 00:17:34 | Train Loss: 0.0001 | Average Loss: 0.0386
# Epoch:40 | Iter:   20 | Time: 00:17:48 | Train Loss: 0.0000 | Average Loss: 0.0380
# Accuracy: 0.927083 | Time: 00:00:01

# %% [markdown]
# **Answer**:
#
# Accuracy on test set: **0.929688**

# %% [markdown]
# ## Submission guidelines
# ---
# We will grade your homework based on your submitted notebook file. We will check the notebook for both results and code. Please make sure you run your code and print out the results in the notebook before submitting (we expect to see the results before running your code by ourselves.)
#
# You submit your homework by first creating a ***google shared link*** of a folder for your homework (described below), and put that link into the ***text submission section*** of your homework submission on Blackboard. ([How to submit your link?](https://drive.google.com/file/d/16-FlPSiu5n-pRezLfcbAvgYxXtGtrs16))
#
# To generate the ***google shared link***, first create a folder named ***Surname_Givenname_SBUID_hw**** in your Google Drive with your CS account (or your SBU account if you don't have a CS account). The structure of the files in the folder should be exactly the same as the one you downloaded. For instance in this homework:
#
# ```
# Surname_Givenname_SBUID_hw4
#         |---CSE527-22F-HW4.ipynb
# ```
# Note that this folder should be in your Google Drive with your account.
#
# Then right click this folder, click ***Get shareable link***, in the People textfield, enter the TAs' email: ***haoyuwu@cs.stonybrook.edu*** and ***vhnguyen@cs.stonybrook.edu***. Make sure that the TAs who have the link **can edit**, ***not just*** **can view**, and also **uncheck** the **Notify people** box. ([How to share link?](https://drive.google.com/file/d/17R6j6yE8_8vXioOB3nNvbEPzxcI-rr_H) )
#
# ***IMPORTANT: Please do not make any modification to the folder and its files after the submission deadline***. (All modifications can be seen by the TAs via the revision history.) Note that in google colab, we will only grade the version of the code right before the timestamp of the submission made in blackboard.
#
# The input and output paths are predefined and **DO NOT** change them, (we assume that 'Surname_Givenname_SBUID_hw1' is your working directory, and all the paths are relative to this directory).  The image read and write functions are already written for you. All you need to do is to fill in the blanks as indicated to generate proper outputs.
#
#
# -- DO NOT change the folder structure, please just fill in the blanks. <br>
#
# You are encouraged to post and answer questions on Piazza. Based on the amount of email that we have received in past years, there might be delays in replying to personal emails. Please ask questions on Piazza and send emails only for personal issues.
#
# If you alter the folder structures, the grading of your homework will be significantly delayed and possibly penalized.
#
# Be aware that your code will undergo plagiarism check both vertically and horizontally. Please do your own work.
#
# Late submission penalty: <br>
# There will be a 10% penalty per day for late submission. However, you will have 4 days throughout the whole semester to submit late without penalty. Note that the grace period is calculated by days instead of hours. If you submit the homework one minute after the deadline, one late day will be counted. Likewise, if you submit one minute after the deadline, the 10% penaly will be imposed if not using the grace period.

# %% [markdown]
# <!--Write your report here in markdown or html-->
